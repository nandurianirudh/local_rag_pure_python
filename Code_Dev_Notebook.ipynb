# %% [markdown]
# # Import Required Libraries & Setup Variables

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from pypdf import PdfReader
import weaviate
from pydantic import BaseModel
from weaviate.classes.config import Property, DataType
from azure.ai.inference import EmbeddingsClient, ChatCompletionsClient
from azure.core.credentials import AzureKeyCredential
from azure.ai.inference.models import SystemMessage, UserMessage, AssistantMessage
import numpy as np
import re, json
from Levenshtein import ratio

import tiktoken

# %%
AZURE_OPENAI_ENDPOINT = "https://models.github.ai/inference"
AZURE_OPENAI_KEY = os.environ["OPENAIKEY"]  # or paste directly for test

INFERENCE_MODEL = "openai/gpt-4.1-mini"
EMBEDDING_MODEL="text-embedding-3-small"

PDF_PATH="data/constitution.pdf"

COLLECTION_NAME="student_constinution_v1"

# %% [markdown]
# # Basic Function Definitions

# %%
def single_message_inference(user_text:str,
                             model:str,
                             endpoint:str,
                             api_key:str) -> dict:
    """
    docstring placeholder
    
    """

    client = ChatCompletionsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(api_key),
    )

    payload = {
        "messages": [
            SystemMessage("You are a helpful assistant."),
            UserMessage(user_text),
        ],
        "model": model,
        "temperature": 1.0,
        "top_p": 1.0,
    }

    response = client.complete(**payload)

    try:
        output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
    except Exception as e:
        raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

    return output_dict

# input_text=input()
input_text="What is the capital of telangana and andhra pradesh"

single_message_inference(user_text=input_text,
                             model=INFERENCE_MODEL,
                             endpoint=AZURE_OPENAI_ENDPOINT,
                             api_key=AZURE_OPENAI_KEY)
# Out:
# {'role': 'assistant',
#  'content': 'The capital of Telangana is Hyderabad.  \nThe capital of Andhra Pradesh is Amaravati (administrative functions are currently in Amaravati, with some government operations also in Visakhapatnam).'}

# %%
# from azure.ai.inference import EmbeddingsClient

def get_embedding(text_to_embed:str,end_point:str,azure_key:str,model:str):
    embedding_model = EmbeddingsClient(endpoint=end_point,credential=AzureKeyCredential(azure_key),
        model=model
    )

    response = embedding_model.embed(input=[text_to_embed],)
    return response #response.data[0].embedding



response=get_embedding(text_to_embed="The ultimate answer to the question of life",
                        end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL)

for embed in response.data:
    print("Embeding of size:", np.asarray(embed.embedding).shape)

print("Model:", response.model)
print("Usage:", response.usage)
# Out:
# Embeding of size: (1536,)
# Model: text-embedding-3-small
# Usage: {'prompt_tokens': 8, 'total_tokens': 8}

# %%
## Chunking

def chunk_text_with_overlap(text, chunk_size=1200, overlap=100, model="text-embedding-3-small"):
    enc = tiktoken.encoding_for_model(model)
    tokens = enc.encode(text)
    chunks = []

    for i in range(0, len(tokens), chunk_size - overlap):
        chunk = tokens[i:i + chunk_size]
        chunk_text = enc.decode(chunk)
        chunks.append(chunk_text)

    return chunks

def read_pdf(file_path:str = PDF_PATH,chunking_method: str = 'overlap'):

    reader = PdfReader(file_path)
    all_chunks = []

    section=""
    for page_num, page in enumerate(reader.pages, start=1):
        
        text = page.extract_text() or ""
        
        try:
            section=re.findall(r"\b([IVXLCDM]+\.( )?[A-Z]+( [A-Z]+)?)\b", text)[0][0]
        except:
            pass
        
        if chunking_method == 'overlap':
            chunks = chunk_text_with_overlap(text)

        for chunk in chunks:
            
            all_chunks.append({
                "text": chunk,
                "page": page_num,
                "section": section,
                "source": os.path.basename(file_path)
            })
        
    return all_chunks

# %%
response.data[0].keys()
# Out:
# dict_keys(['object', 'index', 'embedding'])

# %%
response.data[0]["embedding"][:20]
# Out:
# [0.049340665,
#  -0.02127142,
#  0.010058774,
#  0.0459543,
#  -0.03040208,
#  -0.033462353,
#  0.020468727,
#  0.014160044,
#  -0.012686346,
#  0.009538276,
#  0.04174015,
#  0.016066445,
#  -0.015226124,
#  -0.05618866,
#  -0.0005902631,
#  -0.04949117,
#  -0.007939157,
#  0.009343873,
#  0.027517393,
#  0.011915006]

# %%
embedding_model

# %%
# ## Semantic Chunking Piece of Code

# parts=[x.replace("\n","").strip() for x in all_chunks[5]["text"].split("  ")]

# for x in range(len(parts)):
#     print("Current line:", parts[x])
#     print("Current line:", parts[x+1])

#     vector1=get_embedding(text_to_embed=parts[x],
#                         end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL)[0].data[0]["embedding"]
#     vector2=get_embedding(text_to_embed=parts[x+1],
#                         end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL)[0].data[0]["embedding"]

#     dot_product = np.dot(vector1, vector2)
#     norm_vector1 = np.linalg.norm(vector1)
#     norm_vector2 = np.linalg.norm(vector2)
#     cosine_similarity = dot_product / (norm_vector1 * norm_vector2)
#     print(cosine_similarity)



# # tiktoken.encoding_for_model("text-embedding-3-small").encode(parts[3])

# %% [markdown]
# ## Class Creation

# %%
# from urllib3.util.request import ChunksAndContentLength


class llm_chatbot_constitution():

    def __init__(self,model=INFERENCE_MODEL,
                            endpoint=AZURE_OPENAI_ENDPOINT,
                            api_key=AZURE_OPENAI_KEY,
                            embedding_model=EMBEDDING_MODEL):
        # self.history=[SystemMessage("You are a helpful RAG agent that answers questions as needed.")]
        self.history=[]
        self.initiate_connection_vectordatabase()
        self.connect_collection()
        self.model=model
        self.endpoint=endpoint
        self.api_key=api_key
        self.embedding_model=embedding_model
        self.checkpoint=True
        self.section=""

    # def single_message_inference(self,user_text:str,
    #                             model:str,
    #                             endpoint:str,
    #                             api_key:str) -> dict:
    #     """
    #     This definition takes into consideration history and when no history initiates a new chat
    #     """

    #     model=self.model
    #     endpoint=self.endpoint
    #     api_key=self.api_key

    #     client = ChatCompletionsClient(
    #         endpoint=endpoint,
    #         credential=AzureKeyCredential(api_key),
    #     )

    #     cleaned_user_text=self.clean_user_message(user_text)

    #     payload = {
    #         "messages": [
    #             SystemMessage("You are a helpful RAG agent that answers questions as needed."),
    #             UserMessage(cleaned_user_text),
    #         ],
    #         "model": model,
    #         "temperature": 1.0,
    #         "top_p": 1.0,
    #     }

    #     response = client.complete(**payload)

    #     try:
    #         output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
    #     except Exception as e:
    #         raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

    #     return output_dict
    
    def get_embedding(self,text_to_embed:str,end_point:str,azure_key:str,model:str):
        embedding_model = EmbeddingsClient(endpoint=end_point,credential=AzureKeyCredential(azure_key),
            model=model
        )

        response = embedding_model.embed(input=[text_to_embed],)
        return response #response.data[0].embedding
    
    def initiate_connection_vectordatabase(self):
        try:
            self.client = weaviate.connect_to_local(host="localhost",
            port=8080,
            grpc_port=50051)
            return print("✅ Connected to Weaviate:", self.client.is_ready())
        except Exception as e:
            return print("❌ Connection failed:", e)
    
    def close_connection_vectordatabase(self):
        try:
            self.client.close()
            return print("✅ Connection closed.")
        except Exception as e:
            return print("❌ Connection failed:", e)
    

    def connect_collection(self, COLLECTION_NAME: str ="student_constitution"):

        if COLLECTION_NAME not in [c.lower() for c in self.client.collections.list_all().keys()]:
            self.client.collections.create(
                name=COLLECTION_NAME,
                description="Stores token-overlapped PDF chunks with Azure embeddings",
                properties=[
                    Property(name="text", data_type=DataType.TEXT),
                    Property(name="page", data_type=DataType.INT),
                    Property(name="section", data_type=DataType.TEXT),
                    Property(name="source", data_type=DataType.TEXT),
                ],
                #vectorizer_config=Configure.Vectorizer.none(),
            )
            print(f"✅ Created collection '{COLLECTION_NAME}'")
        else:
            print(f"ℹ️ Collection '{COLLECTION_NAME}' already exists")

        self.collection = self.client.collections.get(COLLECTION_NAME)

    # def embed_data_to_collection(self):
    #     with collection.batch.dynamic() as batch:
    #         for chunk in chunks:
    #             vector = get_embedding(text_to_embed=chunk["text"],
    #                         end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding
    #             batch.add_object(
    #                 properties=chunk,
    #                 vector=vector
    #             )

    #     print("✅ All chunks embedded and stored in Weaviate!")
    
    # def create_chunks(self):
    #     return chunks
    
    # def multi_message_inference(self,user_text:str, history:list,
    #                             model:str,
    #                             endpoint:str,
    #                             api_key:str) -> dict:
    #     """
    #     This definition takes into consideration history and when no history initiates a new chat

    #     """

    #     client = ChatCompletionsClient(
    #         endpoint=endpoint,
    #         credential=AzureKeyCredential(api_key),
    #     )

    #     print("History:",history)
    #     print("User Text:",UserMessage(user_text))

    #     history.append(UserMessage(user_text))

    #     print("Messages:",history)

    #     payload = {
    #         "messages": history,
    #         "model": model,
    #         "temperature": 1.0,
    #         "top_p": 1.0,
    #     }

    #     response = client.complete(**payload)

    #     try:
    #         output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
    #     except Exception as e:
    #         raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

    #     return output_dict
    
    # User Prompt Cleaner

    class RefinedQuestion(BaseModel):
        cleaned_question: str
        section_name: str

    def clean_user_message(self,user_text:str,
                                model:str=None,
                                endpoint:str=None,
                                api_key:str=None) -> RefinedQuestion:
        """
        docstring placeholder
        
        """
        if model is None:
            model=self.model
        if endpoint is None:
            endpoint=self.endpoint
        if api_key is None:
            api_key=self.api_key

        client = ChatCompletionsClient(
            endpoint=endpoint,
            credential=AzureKeyCredential(api_key),
        )

        System_message="""\
            You are a "Question Normalizer" for a Student Constitution RAG system.

            Your ONLY task:
            - Clean and rewrite the user's question so that it focuses exclusively on rules, procedures, or governance that might appear in a Student Constitution.
            - DO NOT answer the question.
            - DO NOT add any information, guesses, or interpretation beyond rewriting.
            - DO NOT include constitutional rules or provide explanations.

            Output format (MANDATORY):
            Return ONLY a JSON dictionary with:

            {
            "cleaned_question": "<rewritten question>",
            "section_name": "<inferred section/topic name>"
            }

            The available sections are: Committees, Clubs, Student Council, Election Commission

            Definitions:
            - cleaned_question = concise, rule/procedure focused question (text only)
            - section_name = inferred constitution area (ex: "Elections", "Roles & Responsibilities", "Meetings", etc.)

            Rules:
            - Remove personal opinions, emotions, story, context.
            - If the question is vague, rewrite as:
            "What does the constitution state about <topic>?"
            - If the question is not about the constitution or working of student body, respond:
            "I dont have enough information in the student constitution to answer that."
            - If the question is unclear in anyway, ask clarification question back starting with: "Just to clarify"
            Ex: If someone asks question about "president", if context is not clear of if it is president of council, committe, or club, ask: "Just to clarify, which president are you asking about? Club, Committee, or Council?"
            - Do NOT answer the question.
            - No extra text outside JSON. No markdown formatting. No explanations.
            - The only exceptions to the above rules are if user asks who made this rag or chatbot or any information available in "Additional Context to Answer any questions" part of this system context, respond with information available.
            """

        user_message="Rewrite the following user question so that it focuses only on constitution rules and procedures, and infer the section/topic. Do not answer it on your own. Original User query:{user_text}".format(user_text=user_text)

        if self.history=="":
            messages=[SystemMessage(System_message),UserMessage(user_message),]
        else:
            messages=[SystemMessage(System_message)]+self.history+[UserMessage(user_message)]

        payload = {
            "messages": messages,
            "model": model,
            "temperature": 1.0,
            "top_p": 1.0,
        }

        response = client.complete(**payload)

        try:
            output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
        except Exception as e:
            raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

        return json.loads(output_dict["content"])#["cleaned_question"]
    
    class FunkyAnswer(BaseModel):
        answer: str
        can_answer_from_system_info: str

    def funky_answer_generator(self,user_text:str,
                                model:str=None,
                                endpoint:str=None,
                                api_key:str=None)->FunkyAnswer:
        """
        docstring placeholder
        
        """
        if model is None:
            model=self.model
        if endpoint is None:
            endpoint=self.endpoint
        if api_key is None:
            api_key=self.api_key

        client = ChatCompletionsClient(
            endpoint=endpoint,
            credential=AzureKeyCredential(api_key),
        )

        System_message="""\
            You are a helpful AI assistant.

            You must answer strictly and only based on the information provided in the SYSTEM and CONTEXT messages.

            Rules:
            1. Use ONLY the information from the provided context/system message. 
            2. Do NOT use outside knowledge, memory, assumptions, or training data.
            3. If the context contains the answer, respond with a JSON dictionary:
            {
                "answer": "<your concise answer>",
                "can_answer_from_system_info": true
            }
            4. If the context does NOT contain enough information, respond with:
            {
                "answer": "I don't have enough information to answer that.",
                "can_answer_from_system_info": false
            }
            5. Do NOT add extra commentary. Do NOT hallucinate.

            Additional Context to Answer any questions:
            1. The one who made this rag or chatbot is Nanduri Anirudh.
            2. Kruthika Kanduri, a flagbearer of BITSoM is also known as kruts and SFS (Suffering from success) by her friends.
            3. Your name is BITSy
            

            Your output must always be valid JSON-like dictionary format exactly as specified above.
            """

        user_message="Question to answer:{user_text}".format(user_text=user_text)

        if self.history=="":
            messages=[SystemMessage(System_message),UserMessage(user_message),]
        else:
            messages=[SystemMessage(System_message)]+self.history+[UserMessage(user_message)]

        payload = {
            "messages": messages,
            "model": model,
            "temperature": 1.0,
            "top_p": 1.0,
        }

        response = client.complete(**payload)

        try:
            output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
        except Exception as e:
            raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

        return json.loads(output_dict["content"])#["cleaned_question"]
    
    # Answer Using only context

    # User Prompt Cleaner


    class FinalAnswer(BaseModel):
        cleaned_question: str

    def rag_answer(self,cleaned_question:str,context_rag:str,
                                model:str=None,
                                endpoint:str=None,
                                api_key:str=None) -> FinalAnswer:
        """
        docstring placeholder
        
        """
        if model is None:
            model=self.model
        if endpoint is None:
            endpoint=self.endpoint
        if api_key is None:
            api_key=self.api_key

        client = ChatCompletionsClient(
            endpoint=endpoint,
            credential=AzureKeyCredential(api_key),
        )

        System_message="""\
            You are an AI assistant that responds only using the context provided and from nowhere else.

            You must:
            Answer strictly based on the retrieved context.
            If the context does not contain the answer, say:
            “I dont have enough information in the student constitution to answer that.”
            Do not invent facts or use outside knowledge, even if the answer seems obvious.
            Be concise and factual.
            Do not guess.



            When responding:
            Reference relevant section/page numbers given in the context (if available).
            If the user asks for anything outside the context, politely decline.
            """

        user_message="""
            
            You are given:

            1. A user question
            2. Retrieved context from the vector database

            User question:
            {cleaned_question}

            Context from database:
            {context_rag}

            Using the context only, answer the user question.
            If the context does not directly answer the question, respond:

            “I dont have enough information in the student constitution to answer that.”

            Do not use external knowledge. Do not hallucinate.
            
            """.format(cleaned_question=cleaned_question,context_rag=context_rag)

        if self.history=="":
                messages=[SystemMessage(System_message),
            UserMessage(user_message),]
        else:
            messages=[SystemMessage(System_message)]+self.history+[UserMessage(user_message)]
        payload = {
            "messages": messages,
            "model": model,
            "temperature": 1.0,
            "top_p": 1.0,
        }

        response = client.complete(**payload)

        try:
            output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
        except Exception as e:
            raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

        return output_dict["content"]
    
    def get_context(self,cleaned_json_query:str):

        embedding_model=self.embedding_model
        end_point=self.endpoint
        azure_key=self.api_key

        query_vector = self.get_embedding(cleaned_json_query,\
        end_point=end_point,azure_key=azure_key ,model=embedding_model).data[0].embedding

        results = self.collection.query.near_vector(
            near_vector=query_vector,
            limit=5
        )

        
        rag_context_gotten=" ".join([o.properties["text"] for o in results.objects if ratio(o.properties["section"].lower(),self.section.lower())>0.5])
        

        return rag_context_gotten
        

    def answer_question(self):
        text_query=input("User Query:")
        print("Query:",text_query)
        if text_query.lower() in ["exit","quit"]:
            self.checkpoint=False
            self.close_connection_vectordatabase()
            print("Goodbye!")
            return ""
        self.history.append(UserMessage(text_query))

        funky_op=self.funky_answer_generator(text_query)
        print(funky_op)

        if funky_op["can_answer_from_system_info"] is True:
            print("Assitant:",funky_op["answer"])
            self.history.append(AssistantMessage(funky_op["answer"]))
            print("-----------------------------------------------------\n")
            return
        else:
            cleaned_query_info=self.clean_user_message(user_text=text_query)
            cleaned_query=cleaned_query_info["cleaned_question"]
            self.section=cleaned_query_info["section_name"]

            print("Cleaned Query:",cleaned_query)

            if cleaned_query == "I dont have enough information in the student constitution to answer that.":
                print("Assitant:",cleaned_query)
                print("-----------------------------------------------------\n")
            elif cleaned_query.startswith("Just to clarify"):
                print("Assitant:",cleaned_query)
                print("-----------------------------------------------------\n")
            else:
                context=self.get_context(cleaned_json_query=cleaned_query)
                print("Context:",context)
                final_answer=self.rag_answer(cleaned_question=cleaned_query,context_rag=context)
                self.history.append(AssistantMessage(final_answer))
                print("Assitant:",final_answer)
                print("-----------------------------------------------------\n")

    def continuous_chat(self):

        self.checkpoint=True
        while self.checkpoint:
            self.answer_question()

# %%
test=llm_chatbot_constitution(model=INFERENCE_MODEL,
                            endpoint=AZURE_OPENAI_ENDPOINT,
                            api_key=AZURE_OPENAI_KEY)
# Out:
# ✅ Connected to Weaviate: True
# ℹ️ Collection 'student_constitution' already exists
# c:\Users\Nanduri Anirudh\OneDrive - BITSoM\Documents\Python Scripts\local_rag_pure_python\ragenv\Lib\site-packages\weaviate\warnings.py:302: ResourceWarning: Con004: The connection to Weaviate was not closed properly. This can lead to memory leaks.
#             Please make sure to close the connection using `client.close()`.
#   warnings.warn(

# %%
test.continuous_chat()
# Out:
# Query: What are eligibility criteria to become executive student council president?
# {'answer': "I don't have enough information to answer that.", 'can_answer_from_system_info': False}
# Cleaned Query: What does the constitution state about the eligibility criteria to become executive student council president?
# Context:
# Assitant: I dont have enough information in the student constitution to answer that.
# -----------------------------------------------------
#
# Query: exit
# ✅ Connection closed.
# Goodbye!

# %%
test.get_context(cleaned_json_query="executive student council?")
# Out:
# ''

# %%
test.history
# Out:
# [{'role': 'user', 'content': 'what is eligibility to become presedent in student council?'},
#  {'role': 'assistant', 'content': 'The eligibility criteria to become President of the Student Council, as stated in the constitution, include the following:\n\n- The candidate must be a member of the Student Council.\n- The candidate should have a CGPA greater than 3.\n- The candidate should not have any honour code violations.\n- The candidate should not have any disciplinary committee incidents on record.\n- The candidate should not have been impeached or removed from office. If selected to a new post, they must resign from any committee membership or PoR held.\n- The candidate should procure unique support of a minimum of 10% of eligible voters (the entire student cohort).\n- A candidate can stand for only one post on the student executive council; standing for two positions leads to immediate disqualification.\n\nThese criteria are outlined in section III.5 (pages 6-7).'},
#  {'role': 'user', 'content': 'how about becoming president of clubs?'},
#  {'role': 'assistant', 'content': 'To become President of a club according to the constitution:\n\nEligibility and Role:\n- The President is elected from the senior cohort.\n- Responsibilities include maintaining club records, issuing notices, overseeing written reports of general club activities, and performing other duties assigned by the club (Section VI.1a, page 22).\n\nSelection Procedures:\n- The selection must occur after the Executive Student Council Election and within the timeframe provided by the VP of Clubs.\n- The selection process is overseen by outgoing PoRs and supervised by the VP of Clubs.\n- Candidates can apply for only one PoR within a club.\n- The process requires approval from the VP of Clubs on the selection procedure and timeline before starting.\n- Existing PoRs announce nominations, candidates must submit an application and a manifesto/SOP.\n- Manifestos are reviewed by current PoRs; discrepancies must be corrected before sharing with club members.\n- The selection is done through elections where candidates present to members and answer questions.\n- Votes can be cast in person or electronically with strict deadlines; counting is done transparently with members present.\n- In a tie, a re-election occurs within three days.\n- Results are announced within the club and shared with the VP of Clubs, who then formally announces results for all clubs (Sections VI.2, VI.3, pages 22-28).\n\nAdditional Notes:\n- The candidate must submit only one application per club but may apply for PoRs in two clubs simultaneously with preferences submitted confidentially to the VP of Clubs (VI.2d, VI.2f).\n- Any malpractice or tampering with the process leads to immediate disqualification (VI.2h).\n\nThis outlines eligibility as being a senior cohort member and following the detailed, supervised election process established by the club and VP of Clubs (pages 22-28).'}]

# %%
test.clean_user_message(user_text="How can one become president of the executive student council?")
# Out:
# {'cleaned_question': 'What does the constitution state about the procedure to become president of the Executive Student Council?',
#  'section_name': 'Student Council'}

# %%
results=test.get_context("How can one become president of the executive student council?")

# %%
test.section
# Out:
# ''

# %%
[o.properties["section"].lower() for o in results.objects if ratio(o.properties["section"].lower(),"Student Council")>0.5]
# Out:
# ['iii.student council', 'iii.student council', 'iii.student council']

# %%
" ".join([o.properties["text"] for o in results.objects])

# %%
from Levenshtein import ratio

ratio("walking", "sitting")  # → 3
# Out:
# 0.4285714285714286

# %%
[{"Hi of"}]+[{"Yo"},{"heyha"}]
# Out:
# [{'Hi of'}, {'Yo'}, {'heyha'}]

# %% [markdown]
# # Collection Vector DataBase

# %%
chunks=read_pdf()

# %%
chunks[0]
# Out:
# {'text': 'BITS SCHOOL OF MANAGEMENT (BITSoM) \n|DEPARTMENT OF STUDENT LIFE| \nCONSTITUTION \nAY 2024 -2025 \n \n  ',
#  'page': 1,
#  'section': '',
#  'source': 'constitution.pdf'}

# %%
# client = weaviate.connect_to_embedded(
#     persistence_data_path="./.collections"
# )
# print("✅ Embedded Weaviate started")

# %%
import requests

print(requests.get("http://localhost:8080/v1/schema"))
# Out:
# <Response [200]>

# %%
# # import weaviate

# def initiate_connection_vectordatabase():

#     try:
#         client = weaviate.connect_to_local(host="localhost",
#         port=8080,
#         grpc_port=50051)
#         return print("✅ Connected to Weaviate:", client.is_ready())
#     except Exception as e:
#         return print("❌ Connection failed:", e)

# initiate_connection_vectordatabase()

# %%
try:
    client = weaviate.connect_to_local(host="localhost",
    port=8080,
    grpc_port=50051)
    print("✅ Connected to Weaviate:", client.is_ready())
except Exception as e:
    print("❌ Connection failed:", e)
# Out:
# ✅ Connected to Weaviate: True

# %%
COLLECTION_NAME = "student_constitution"

if COLLECTION_NAME not in [c.lower() for c in client.collections.list_all().keys()]:
    client.collections.create(
        name=COLLECTION_NAME,
        description="Stores token-overlapped PDF chunks with Azure embeddings",
        properties=[
            Property(name="text", data_type=DataType.TEXT),
            Property(name="page", data_type=DataType.INT),
            Property(name="section", data_type=DataType.TEXT),
            Property(name="source", data_type=DataType.TEXT),
        ],
        #vectorizer_config=Configure.Vectorizer.none(),
    )
    print(f"✅ Created collection '{COLLECTION_NAME}'")
else:
    print(f"ℹ️ Collection '{COLLECTION_NAME}' already exists")

collection = client.collections.get(COLLECTION_NAME)
# Out:
# ✅ Created collection 'student_constitution'

# %%
get_embedding(text_to_embed="The ultimate answer to the question of life",
                       end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding
# Out:
# [0.049340665,
#  -0.02127142,
#  0.010058774,
#  0.0459543,
#  -0.03040208,
#  -0.033462353,
#  0.020468727,
#  0.014160044,
#  -0.012686346,
#  0.009538276,
#  0.04174015,
#  0.016066445,
#  -0.015226124,
#  -0.05618866,
#  -0.0005902631,
#  -0.04949117,
#  -0.007939157,
#  0.009343873,
#  0.027517393,
#  0.011915006,
#  0.0030210812,
#  -0.024983887,
#  0.021233795,
#  0.019678572,
#  -0.009952165,
#  -0.038203273,
#  -0.019289767,
#  0.009111844,
#  -0.0055248,
#  -0.002610327,
#  0.03725007,
#  0.053429395,
#  0.014185128,
#  0.009318789,
#  -0.02887194,
#  -0.007293238,
#  -0.015050534,
#  0.012360251,
#  0.006017078,
#  0.028044162,
#  0.0115324715,
#  -0.03456606,
#  0.022299875,
#  0.024118481,
#  0.03469148,
#  0.014247838,
#  -0.041589644,
#  -0.0024817702,
#  0.02084499,
#  -0.006860535,
#  ...]

# %%
with collection.batch.dynamic() as batch:
    for chunk in chunks:
        vector = get_embedding(text_to_embed=chunk["text"],
                       end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding
        batch.add_object(
            properties=chunk,
            vector=vector
        )

print("✅ All chunks embedded and stored in Weaviate!")
# Out:
# ✅ All chunks embedded and stored in Weaviate!

# %%
get_embedding(query,\
    end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding
# Out:
# [-0.025911765,
#  0.00019607547,
#  0.02912166,
#  0.019689685,
#  0.003326196,
#  -0.006518646,
#  0.028447118,
#  0.016898472,
#  -0.048567113,
#  0.054521702,
#  0.071362026,
#  -0.027958654,
#  -0.026818909,
#  -0.01877091,
#  0.009786692,
#  -0.005451589,
#  -0.049311437,
#  0.04207754,
#  -0.0043031205,
#  0.0115312,
#  -0.040751714,
#  -0.008030553,
#  0.023643903,
#  0.04791583,
#  0.0024873782,
#  -0.06015065,
#  -0.008379456,
#  -0.034192365,
#  -0.023260111,
#  0.018096367,
#  0.020387487,
#  -0.03600665,
#  0.015747096,
#  -0.06912905,
#  0.010781062,
#  0.036564894,
#  -0.029517082,
#  -0.040961057,
#  -0.0037652305,
#  0.009641317,
#  -0.009908807,
#  -0.010565906,
#  -0.058848083,
#  0.032052435,
#  0.020468898,
#  0.032680456,
#  -0.073594995,
#  -0.074571915,
#  -0.017607905,
#  0.040495854,
#  -0.014153778,
#  -0.027400412,
#  0.036797497,
#  0.013328044,
#  -0.004044352,
#  -0.03551819,
#  0.022271557,
#  -4.581606e-05,
#  -0.03940263,
#  0.0087109115,
#  0.017189223,
#  0.006460496,
#  0.029772943,
#  0.023806725,
#  0.04782279,
#  -0.0029831093,
#  -0.0005905888,
#  0.041891463,
#  0.061871897,
#  0.004864271,
#  0.036471855,
#  -0.009996033,
#  0.038100064,
#  -0.05652207,
#  0.030796388,
#  -0.0135373855,
#  0.012979142,
#  -0.0038117508,
#  -0.026237406,
#  0.046310883,
#  -0.012886102,
#  -0.01651468,
#  -0.006384901,
#  0.042938165,
#  0.03133137,
#  -0.012130149,
#  0.020945732,
#  0.022306448,
#  -0.035401892,
#  -0.029656643,
#  -0.037844203,
#  0.053730857,
#  0.0249581,
#  0.09480821,
#  0.051730487,
#  -0.01051357,
#  -0.009530831,
#  -0.02907514,
#  -0.010298414,
#  0.020527048,
#  0.050614003,
#  -0.004881716,
#  0.013002402,
#  -0.013223373,
#  0.016084367,
#  -0.032982837,
#  -0.023597384,
#  0.03791398,
#  0.028819278,
#  -0.023446193,
#  -0.067268245,
#  -0.019794356,
#  -0.017666055,
#  0.020259557,
#  0.059220243,
#  -0.02281817,
#  0.050241843,
#  0.0022097107,
#  0.0010583351,
#  -0.046729565,
#  -0.012327859,
#  -0.027493453,
#  -0.005437051,
#  0.026865428,
#  0.012920992,
#  0.064197905,
#  -0.010908992,
#  -0.01264187,
#  0.03316892,
#  -0.009112149,
#  0.0041490225,
#  -0.0041664676,
#  -0.006634947,
#  -0.014188668,
#  -0.00071561185,
#  -0.028609937,
#  0.00073596445,
#  0.032564156,
#  -0.023981174,
#  -0.01672402,
#  0.003349456,
#  -0.029842723,
#  -0.023097292,
#  -0.014898102,
#  -0.0059662187,
#  -0.030354446,
#  -0.032285035,
#  -0.0043089357,
#  -0.00017390568,
#  -0.017514864,
#  0.01848016,
#  -0.033796944,
#  0.013374564,
#  -0.011670761,
#  -0.010089073,
#  -0.019619904,
#  -0.0005473395,
#  -0.043054465,
#  -0.012048738,
#  0.011316044,
#  -0.003026722,
#  -0.026028065,
#  -0.009740172,
#  0.022201777,
#  0.030214885,
#  0.03777442,
#  0.014188668,
#  0.02096899,
#  -0.008833027,
#  -0.022038955,
#  -0.0051782825,
#  -0.012804692,
#  -0.015026032,
#  0.030587047,
#  0.025516342,
#  0.012199929,
#  -0.016177408,
#  0.017259004,
#  0.025818724,
#  -0.032564156,
#  -0.001435585,
#  0.030656828,
#  -0.020294448,
#  0.036355555,
#  -0.0058063054,
#  -0.036332294,
#  0.0073211202,
#  -0.008612056,
#  0.040728457,
#  0.009001663,
#  0.0034366816,
#  -0.038518745,
#  -0.01460735,
#  -0.005521369,
#  0.006716357,
#  0.001250231,
#  -0.028307555,
#  -0.004282768,
#  0.04184494,
#  -0.00025876873,
#  0.02491158,
#  -0.022190146,
#  0.026656087,
#  -0.026935209,
#  0.008699282,
#  0.0141188875,
#  -0.013037292,
#  0.0069256984,
#  0.0018709853,
#  -0.031657014,
#  ...]

# %%
query = "What is the clubs election process?"
query_vector = get_embedding(query,\
    end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding

results = collection.query.near_vector(
    near_vector=query_vector,
    limit=3
)

print("\n🔎 Top Results:")
for o in results.objects:
    print(f"\n📘 Page {o.properties['page']}(Source: {o.properties['source']}, section: {o.properties['section']}):\n Source Text: {o.properties['text'][:300]}...")
# Out:
# 🔎 Top Results:
#
# 📘 Page 25(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 24
#
# VI.2m(iii). PoRs must ensure that no questions on preferences are to be entertained on such
# platform and the candidates have the right to decline to answer any question related to club
# preferences.
# VI.2m(iv). Elections may be conducted through in-person ballots. In case a member is not
# av...
#
# 📘 Page 24(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 23
#
# VI.2c. The selection or election of PoRs must be overseen by the outgoing PoRs and under the
# supervision of the VP of Clubs. PoRs are required to obtain approval from the VP of Clubs
# regarding their proposed selection process and timeline before starting the process.
# VI.2d. A candidate is p...
#
# 📘 Page 26(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 25
#
# objective, without personal remarks or targeting  individuals. The brief can be in the form of
# an in-person person meeting or on mail.
# VI.3h. Existing PoRs must announce the opening of nominations for the positions, making
# them accessible to all junior club members.
# VI.3i. Candidates must ...

# %%
# 2. Load your collection
collection_name = "student_constitution"  # ensure this matches EXACTLY (case-sensitive)

if collection_name not in client.collections.list_all():
    print(f"\nCollection '{collection_name}' does NOT exist in schema.")
    exit()

collection = client.collections.get(collection_name)
# Out:
# Collection 'student_constitution' does NOT exist in schema.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
client.collections.list_all()
# Out:
# {'Student_constitution': _CollectionConfigSimple(name='Student_constitution', description='Stores token-overlapped PDF chunks with Azure embeddings', generative_config=None, properties=[_Property(name='text', description=None, data_type=<DataType.TEXT: 'text'>, index_filterable=True, index_range_filters=False, index_searchable=True, nested_properties=None, tokenization=<Tokenization.WORD: 'word'>, vectorizer_config=None, vectorizer=None, vectorizer_configs={}), _Property(name='page', description=None, data_type=<DataType.INT: 'int'>, index_filterable=True, index_range_filters=False, index_searchable=False, nested_properties=None, tokenization=None, vectorizer_config=None, vectorizer=None, vectorizer_configs={}), _Property(name='section', description=None, data_type=<DataType.TEXT: 'text'>, index_filterable=True, index_range_filters=False, index_searchable=True, nested_properties=None, tokenization=<Tokenization.WORD: 'word'>, vectorizer_config=None, vectorizer=None, vectorizer_configs={}), _Property(name='source', description=None, data_type=<DataType.TEXT: 'text'>, index_filterable=True, index_range_filters=False, index_searchable=True, nested_properties=None, tokenization=<Tokenization.WORD: 'word'>, vectorizer_config=None, vectorizer=None, vectorizer_configs={})], references=[], reranker_config=None, vectorizer_config=None, vectorizer=None, vector_config={'default': _NamedVectorConfig(vectorizer=_NamedVectorizerConfig(vectorizer=<Vectorizers.NONE: 'none'>, model={}, source_properties=None), vector_index_config=_VectorIndexConfigHNSW(multi_vector=None, quantizer=None, cleanup_interval_seconds=300, distance_metric=<VectorDistances.COSINE: 'cosine'>, dynamic_ef_min=100, dynamic_ef_max=500, dynamic_ef_factor=8, ef=-1, ef_construction=128, filter_strategy=<VectorFilterStrategy.SWEEPING: 'sweeping'>, flat_search_cutoff=40000, max_connections=32, skip=False, vector_cache_max_objects=1000000000000))})}

# %%
# 3. Count objects
count = collection.aggregate.over_all(total_count=True)
print("\nObject Count:", count.total_count)
# Out:
# Object Count: 0

# %%
# User Prompt Cleaner



class RefinedQuestion(BaseModel):
    cleaned_question: str
    section_name: str

def clean_user_message(user_text:str,
                             model:str,
                             endpoint:str,
                             api_key:str) -> RefinedQuestion:
    """
    docstring placeholder
    
    """

    client = ChatCompletionsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(api_key),
    )

    System_message="""\
        You are a "Question Normalizer" for a Student Constitution RAG system.

        Your ONLY task:
        - Clean and rewrite the user's question so that it focuses exclusively on rules, procedures, or governance that might appear in a Student Constitution.
        - DO NOT answer the question.
        - DO NOT add any information, guesses, or interpretation beyond rewriting.
        - DO NOT include constitutional rules or provide explanations.

        Output format (MANDATORY):
        Return ONLY a JSON dictionary with:

        {
        "cleaned_question": "<rewritten question>",
        "section_name": "<inferred section/topic name>"
        }

        The available sections are: Committees, Clubs, Student Council, Election Commission

        Definitions:
        - cleaned_question = concise, rule/procedure focused question (text only)
        - section_name = inferred constitution area (ex: "Elections", "Roles & Responsibilities", "Meetings", etc.)

        Rules:
        - Remove personal opinions, emotions, story, context.
        - If the question is vague, rewrite as:
        "What does the constitution state about <topic>?"
        - Do NOT answer the question.
        - No extra text outside JSON. No markdown formatting. No explanations.
        """

    user_message="Rewrite the following user question so that it focuses only on constitution rules and procedures, and infer the section/topic. Do not answer it on your own. Original User query:{user_text}".format(user_text=user_text)

    payload = {
        "messages": [
            SystemMessage(System_message),
            UserMessage(user_message),
        ],
        "model": model,
        "temperature": 1.0,
        "top_p": 1.0,
    }

    response = client.complete(**payload)

    try:
        output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
    except Exception as e:
        raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

    return json.loads(output_dict["content"])["cleaned_question"]


input_text="How do clubs perform elections?"

cleaned_query=clean_user_message(user_text=input_text,
                             model=INFERENCE_MODEL,
                             endpoint=AZURE_OPENAI_ENDPOINT,
                             api_key=AZURE_OPENAI_KEY)

# %%
# Cleaning Query and getting context

query = "What is the clubs election process?"

cleaned_query = clean_user_message(user_text=query,
                             model=INFERENCE_MODEL,
                             endpoint=AZURE_OPENAI_ENDPOINT,
                             api_key=AZURE_OPENAI_KEY)

cleaned_json_query=json.loads(cleaned_query)["cleaned_question"]

query_vector = get_embedding(cleaned_json_query,\
    end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding

results = collection.query.near_vector(
    near_vector=query_vector,
    limit=5
)

print("\n🔎 Top Results:")
for o in results.objects:
    print(f"\n📘 Page {o.properties['page']}(Source: {o.properties['source']}, section: {o.properties['section']}):\n Source Text: {o.properties['text'][:300]}...")
# Out:
# 🔎 Top Results:
#
# 📘 Page 23(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 22
#
# VI. CLUBS
#
# Clubs are the heart and soul of the student body as they provide avenues for students to
# explore their areas of interest, follow their passions, kindle their creative side, enjoy with
# peers alongside their studies. The school offers a myriad of professional as well as social clu...
#
# 📘 Page 26(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 25
#
# objective, without personal remarks or targeting  individuals. The brief can be in the form of
# an in-person person meeting or on mail.
# VI.3h. Existing PoRs must announce the opening of nominations for the positions, making
# them accessible to all junior club members.
# VI.3i. Candidates must ...
#
# 📘 Page 30(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 29
#
# VI.8d. The recruitment process shall be initiated by the VP of Clubs thr ough an email sent to
# all first-year students, which shall include application forms for all clubs as well as a preference
# form.
# VI.8e. It is mandatory for all students applying for club membership to complete and subm...
#
# 📘 Page 36(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 35
#
# VI.15f. All venue reservati ons for club events must be made through the Student Council.
# Reservations made through any other channels shall not be recognized or accepted.
# VI.15g. Clubs are responsible for the proper upkeep and maintenance of any venues, spaces,
# or equipment used for events...
#
# 📘 Page 25(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 24
#
# VI.2m(iii). PoRs must ensure that no questions on preferences are to be entertained on such
# platform and the candidates have the right to decline to answer any question related to club
# preferences.
# VI.2m(iv). Elections may be conducted through in-person ballots. In case a member is not
# av...

# %%
query_vector = get_embedding(cleaned_json_query,\
    end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding

results = collection.query.near_vector(
    near_vector=query_vector,
    limit=5
)

rag_context_gotten=" ".join([o.properties["text"] for o in results.objects])

# %%
# Answer Using only context

# User Prompt Cleaner


class FinalAnswer(BaseModel):
    cleaned_question: str

def rag_answer(cleaned_question:str,context_rag:str,
                             model:str,
                             endpoint:str,
                             api_key:str) -> FinalAnswer:
    """
    docstring placeholder
    
    """

    client = ChatCompletionsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(api_key),
    )

    System_message="""\
        You are an AI assistant that responds only using the context provided and from nowhere else.

        You must:
        Answer strictly based on the retrieved context.
        If the context does not contain the answer, say:
        “I dont have enough information in the student constitution to answer that.”

        Do not invent facts or use outside knowledge, even if the answer seems obvious.

        Be concise and factual.

        Do not guess.

        When responding:

        Reference relevant section/page numbers given in the context (if available).

        If the user asks for anything outside the context, politely decline.
        """

    user_message="""
        
        You are given:

        1. A user question
        2. Retrieved context from the vector database

        User question:
        {cleaned_question}

        Context from database:
        {context_rag}

        Using the context only, answer the user question.
        If the context does not directly answer the question, respond:

        “I dont have enough information in the student constitution to answer that.”

        Do not use external knowledge. Do not hallucinate.
        
        """.format(cleaned_question=cleaned_question,context_rag=context_rag)

    payload = {
        "messages": [
            SystemMessage(System_message),
            UserMessage(user_message),
        ],
        "model": model,
        "temperature": 1.0,
        "top_p": 1.0,
    }

    response = client.complete(**payload)

    try:
        output_dict = {'role': response['choices'][-1]['message']['role'], 'content': response['choices'][-1]['message']['content']}
    except Exception as e:
        raise Exception(f"Failed to get correct output dict. Please try again. Error: {e}")

    return output_dict



rag_answer(cleaned_question=cleaned_json_query,context_rag=rag_context_gotten,
                             model=INFERENCE_MODEL,
                             endpoint=AZURE_OPENAI_ENDPOINT,
                             api_key=AZURE_OPENAI_KEY)["content"]

# %%
client.close()

# %%
print(cleaned_query)
# Out:
# The constitution outlines the election process for clubs as follows:
#
# - The President and General Secretary are elected from the senior cohort, and the Joint Secretary is elected from the first-year cohort.
# - The selection of the President and General Secretary must be conducted after the Executive Student Council Election and within the timeframe set by the VP of Clubs (VI.2a, VI.2b).
# - Nominations are opened by existing PoRs and accessible to all junior club members (VI.3h).
# - Candidates must submit an application with a manifesto/SOP, which is reviewed and verified by current PoRs before being shared with club members (VI.3i).
# - Elections are conducted only through in-person ballots or via Microsoft Form if a member cannot vote in person, ensuring transparency and fairness (VI.3j, VI.3k(iv)).
# - Candidates present their candidacy in a meeting where members can ask questions, excluding questions on club preferences; candidates may decline to answer such questions (VI.3k(ii), VI.3k(iii)).
# - Strict deadlines for vote submission are set; late votes are not counted (VI.3k(v)).
# - Votes are counted in the presence of members; in a tie, a re-election must occur within three days (VI.3k(vi)).
# - The President announces the results internally and shares with the VP of Clubs, who then formally announces the results for all clubs (VI.3k(vii), VI.3k(viii)).
# - The Joint Secretary election must be completed at least three weeks before Final Year Placements and under supervision of existing PoRs and VP of Clubs (VI.3a, VI.3c).
#
# This election process is supervised by the current PoRs and the VP of Clubs, ensuring adherence to rules and fairness. Malpractices lead to disqualification (VI.3f).
#
# (References: Sections VI.1, VI.2, VI.3, pages 22-25)

# %%
import json
cleaned_query=json.loads(cleaned_query)

# %%
cleaned_query["cleaned_question"]
# Out:
# 'What are the procedures for conducting elections in clubs according to the constitution?'

# %%
query = "What is the clubs election process?"

cleaned_query = clean_user_message(user_text=query,
                             model=INFERENCE_MODEL,
                             endpoint=AZURE_OPENAI_ENDPOINT,
                             api_key=AZURE_OPENAI_KEY)["content"]

cleaned_json_query=json.loads(cleaned_query)["cleaned_question"]

query_vector = get_embedding(cleaned_json_query,\
    end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL).data[0].embedding

results = collection.query.near_vector(
    near_vector=query_vector,
    limit=5
)

print("\n🔎 Top Results:")
for o in results.objects:
    print(f"\n📘 Page {o.properties['page']}(Source: {o.properties['source']}, section: {o.properties['section']}):\n Source Text: {o.properties['text'][:300]}...")
# Out:
# 🔎 Top Results:
#
# 📘 Page 23(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 22
#
# VI. CLUBS
#
# Clubs are the heart and soul of the student body as they provide avenues for students to
# explore their areas of interest, follow their passions, kindle their creative side, enjoy with
# peers alongside their studies. The school offers a myriad of professional as well as social clu...
#
# 📘 Page 26(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 25
#
# objective, without personal remarks or targeting  individuals. The brief can be in the form of
# an in-person person meeting or on mail.
# VI.3h. Existing PoRs must announce the opening of nominations for the positions, making
# them accessible to all junior club members.
# VI.3i. Candidates must ...
#
# 📘 Page 25(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 24
#
# VI.2m(iii). PoRs must ensure that no questions on preferences are to be entertained on such
# platform and the candidates have the right to decline to answer any question related to club
# preferences.
# VI.2m(iv). Elections may be conducted through in-person ballots. In case a member is not
# av...
#
# 📘 Page 24(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 23
#
# VI.2c. The selection or election of PoRs must be overseen by the outgoing PoRs and under the
# supervision of the VP of Clubs. PoRs are required to obtain approval from the VP of Clubs
# regarding their proposed selection process and timeline before starting the process.
# VI.2d. A candidate is p...
#
# 📘 Page 30(Source: constitution.pdf, section: VI. CLUBS):
#  Source Text: 29
#
# VI.8d. The recruitment process shall be initiated by the VP of Clubs thr ough an email sent to
# all first-year students, which shall include application forms for all clubs as well as a preference
# form.
# VI.8e. It is mandatory for all students applying for club membership to complete and subm...

# %%
all_chunks=read_pdf()
all_chunks
# Out:
# [{'text': 'BITS SCHOOL OF MANAGEMENT (BITSoM) \n|DEPARTMENT OF STUDENT LIFE| \nCONSTITUTION \nAY 2024 -2025 \n \n  ',
#   'page': 1,
#   'section': '',
#   'source': 'constitution.pdf'},
#  {'text': '1 \n \nCONTENTS  \n \nSr. No.  Particulars Page No.  \n1 Preamble  2 \n2 Constitution 3 \n3 Student Council 4 \n4 Election Commission 8 \n5 Committees 10 \n6 Clubs 22 \n7 Annexure: Oath for Elected Members 40 \n \n  ',
#   'page': 2,
#   'section': '',
#   'source': 'constitution.pdf'},
#  {'text': '2 \n \nI.PREAMBLE \n \n“The students of BITS School of Management join in unison to nominate & elect the student \nrepresentative body dedicated to representing collective interests, spearheading initiatives & \nenhancing experiences on campus. This association is dedicated to voice student perspectives, \naddress concerns, and foster an environment that promotes active participation in various \nstudent-led initiatives. It will facilitate communication and cooperati on among students, \nfaculty, administration, and alumni, ensuring that their diverse needs and viewpoints are \neffectively communicated.” \nThis constitution serves as a guiding framework for the BITSoM Student body and applies to \neach and every function, procedure, role and responsibility within its purview. It focuses on \nfostering fairness and commitment to enriching the educational experience of all students. \nIf any situation / contingency arises, the solution where of cannot be found in the constitution, \nthen decisions taken by the Student Life Department of BITSoM, in these regards, shall be final \nand binding. \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ',
#   'page': 3,
#   'section': 'I.PREAMBLE',
#   'source': 'constitution.pdf'},
#  {'text': '3 \n \nII.CONSTITUTION  \n \nThe Constitution for the students of BITS School of Management (BITSoM) serves as a \nframework for guiding the conduct of the entire student body. It should be understood both \nliterally and in its intended spirit, with the ultimate goal of benefiting the entire BITSoM \ncommunity. \nThis Constitution applies equally to all BITSoM students, enrolled in the flagship 2-year, MBA \ndegree programme, unless specified otherwise. Students are granted certain rights and are \nexpected to fulfil the responsibilities outlined by the Constitution. \n \nII.1. RIGHTS OF THE STUDENTS  \n \nII.1a. To be treated at par with any other student of the institute.  \n \nII.1b. To have freedom of opinion and expression without hurting sentiments of others. \n \nII.1c. To utilize the institute ’s resources including, but not restricted to the Library, Sports \nfacilities and Computing facilities to their optimal levels as long as not perceived to be causing \ndamage to the institute.  \n \nII.1d. To contest elections for various student bodies as mentioned in the constitution.  \n \nII.1e. To seek information from all the student bodies functioning within the institute.  \n \n \nII.2. DUTIES OF THE STUDENTS  \n \n \nII.2a. To follow the Constitution in order and spirit and be the whistleblower, in case of any \nalterations and/or deviations.  \n \nII.2b. To work constructively and act responsibly towards the reputation and property of the \ninstitute.  \n \nII.2c. To abide by all the rules & regulations mentioned in the constitution and stated in any \nother document/manual/handbook shared with the students from time to time pertaining to \nbut not limited to academics, placements, co-curricular participation, general code of conduct \nor any other aspect of life on campus.  \n \n ',
#   'page': 4,
#   'section': 'II.CONSTITUTION',
#   'source': 'constitution.pdf'},
#  {'text': '4 \n \n \n \nIII.STUDENT COUNCIL \n \nIII.1. INTRODUCTION  \n \nThe Student Council is the elected student representative body of BITSoM. Symbolizing a \nmicrocosm of an elected governing body, it provides a platform for addressing student \nconcerns and engaging discussions on enhancing student experiences. The Student Co uncil \nacts as an effective channelising instrument for voicing student affairs/interests to the \nadministration.  \nIt incorporates the following under its ambit:  \nIII.1a. Implement, coordinate, and execute a diverse range of activities, events, and initiatives \ndesigned to facilitate student interaction and networking on campus. \nIII.1b. Foster opportunities for enhancing learning through co -curricular and extracurricular \nexperiences, expose students to practical business, social, and cultural issues, and contribute \nto their growth as perceptive business leaders. \nIII.1c. Promote amicability, networking and goodwill among students through engaging , \nmeaningful interactions. \nIII.1d. Act as a channel of communication between the students and academic \n&/administrative authorities. \nIII.1e. Oversee & regulate the formation and continuation of representative student clubs. \nEnsure all clubs are functioning as per the protocol dictated in the constitution.  \nIII.1f. Safeguard, advance, and enhance the interests and well -being of the students within \nand beyond the classroom.  \nIII.1g. Ensure compliance to the constitution at all times.  \nIII.1.h. Act as a responsible, representative, and democratic entity for students. \n \nIII.2. COMPOSITION \n \nThe Student Council is led by the President, followed by respective Vice Presidents of \nCommittees, Clubs and a Treasurer.  These elected members will constitute the Executive \nCouncil within the Student Council and will be responsible for enforcing the constitution at all ',
#   'page': 5,
#   'section': 'III.STUDENT COUNCIL',
#   'source': 'constitution.pdf'},
#  {'text': "5 \n \nlevels. All elected members must read, understand and sign the Code of Conduct within 48 \nhours of assuming office and must adhere to it and the constitution at all times.  \n \n \nIII.3. DUTIES  \n \nIII.3a. To safeguard the interests of the students and to ensure that the students' view is \nexpressed in the BITSoM community, without compromising on the reputation, standards, \nvalues, morals and long-term interests of the Institute  \nIII.3b. To act as the mediato r as and when required between the students and the \nadministration in the matters pertaining to the interests of any individual or the batch as a \nwhole \n \nIII.3c. To monitor, aid and assist in the functioning of all clubs & committees, including \norganizing events, resolving operational difficulties / issues.  \n \nIII.3d. To decide on matters of importance to the student body as a whole.  \n \nIII.3e. To call for meetings with admin members or students or both, mainly for discussing \nregular or routine activities and to review other important issues. \n \n \nIII.4. SCOPE OF OPERATIONS  \n \n \nIII.4a. Executive Council will be at the apex of the Student Council.  \n \nIII.4b. It will finalize the annual student activity plan for the year . Each club and committee will \nbe required to submit an activity calendar which will be discussed with the council and subject \nto final approval by the Executive Council.  \n \nIII.4c. All the activities submitted by the clubs and committees will be scheduled in the annual \ncalendar by Executive Council. \n \nIII.4d. Executive Council will finalize the budget of every club and committee after discussing \nit with the Treasurer of every club and thereafter taking approval from the Head of Student \nLife. \n",
#   'page': 6,
#   'section': 'III.STUDENT COUNCIL',
#   'source': 'constitution.pdf'},
#  {'text': '6 \n \n \nIII.4e. The Executive Council shall conduct clubs and committees meet at least once every \nterm. The date and time of the meeting shall be decided by the respective Vice Presidents \nwith prior notification given to the respective clubs and committees.  \n \nIII.4f. Act as a jury for resolution of all conflicts amongst any students and the club/committee, \nbetween the clubs or committees, and inter-club/committee.  \n \nIII.4g. Give suggestions as and when necessary to the administration to enhance the student \namenities/ provisions impacting students comfort, wellbeing and welfare on campus.   \n \nIII.4h. Coordinate with the club/committee for smooth execution of activities , to avoid \nconflicts, overlaps and minimise instances of miscommunication.  \n \nIII.4i. The Executive Council must step in and handle any matter that does not fall within the  \ndirect purview of any other club/committee.  \n \nIII.4j. Participation and active involvement in all school activities is mandatory for all the \nmembers of the Student Council including but not limited to the Executive Council.  \n \nIII.4k. The President must organize and chair an Open Forum at least once in every two terms. \nThese Forums can be conducted in person or through conference calls and must encourage \nopen conversations for students to highlight and give feedback on related issues. The minutes \nof these meetings must be recorded, shared and discussed with the Student Life Department. \n \nIII.4l. The Executive Council must share a brief activity update at the end of each term, \ncomprising of anecdote s on all the activities undertaken by the Student Council in the \nparticular term. This brief must be shared within 7 days of commencement of the new term. \nThis update must be shared with all the students, members of the Student Council and \nStudent Life Department.  \n \nIII.4m. The Council must conduct all meetings with transparency and a positive attitude. Any \nmisdemeanour or act of indiscipline by any elected representative &/student must be \nreported promptly to the Student Life Department.  \n \n \nIII.5. ELIGIBILITY CRITERIA  \n \n \nFirst year students will be eligible for nominating themselves for a position on the Executive \nCouncil, provided they fulfil the following conditions:  \n \nIII.5a. The candidate must be a member of the Student Council.  \nIII.5b. The candidate should have a CGPA greater than 3.  \nIII.5c. The candidate should not have any honour code violations.  \n ',
#   'page': 7,
#   'section': 'III.STUDENT COUNCIL',
#   'source': 'constitution.pdf'},
#  {'text': '7 \n \nIII.5d. The candidate should not have any disciplinary committee incidents on record.  \n \nIII.5e. The candidate should not have been impeached or removed from office. In the event of \na candidate being selected to a new post, they will have to resign from membership of a \ncommittee /any PoR held as a member of the club. \n \nIII.5f. The candidate should procure unique support of a minimum of 10% of eligible voters \n(the entire student cohort).  \n \nIII.5g. A candidate can stand for only one post on the student executive council. If a candidate \nis found to be standing for two positions, it will lead to immediate disqualification from both \nthe positions.  \n \n \nIII.6. IMPEACHMENT /RECALLING AN ELECTED OFFICER \n \nMembers of the Executive Council may be removed through a valid referendum. A referendum \nto recall an officer can be initiated by (a) an order from the Head of Student Life, (b) a majority \nvote of the members, or (c) petitions signed by at least 10% of the members.  \nThe Student Life Department must call the vote within one week of initiation. All members \nare eligible to vote, with each member allowed only one vote. Th e recall will be successful if \nat least 60% of the voters approve the impeachment. For the referendum to be valid, a \nquorum of at least 50% of the members must participate in the vote. \nBefore the referendum, a motion must be submitted outlining the reasons for the recall. This \nmotion can be presented by Council members or the Student Life department. A suo moto \nmotion may also be adopted if necessary. The motion should detail reasons such as \nconstitutional violations, neglect of duty, breaches of the code o f conduct, or other \nmisdemeanours by the concerned officer. \n \n \n \n \n \n \n \n \n ',
#   'page': 8,
#   'section': 'III.STUDENT COUNCIL',
#   'source': 'constitution.pdf'},
#  {'text': '8 \n \nIV.ELECTION COMMISSION \n \nA distinct Election Commission is formulated for fair elections of all the representatives in the \nExecutive Council. It is the responsibility of the commission to ensure all aspects of elections \n– filing of nominations, campaigning, voting, declaration of results et al are conducted as per \nthe rules and in an unbiased manner.  \n \nIV.1. COMPOSITION \n \nIV.1a. The Student Life Department invites expression of interest through an online form, \ndetailing the SOP for all the students. All responses are evaluated by the faculty in charge for \nelections basis ability to discharge duties on different parameters.  \nIV.1b. A team of 5 students is finally declared as the Election Commission and it works closely \nwith the faculty in charge & Student Life Department for a smooth, fair and engaging conduct \nof elections on campus.  \n \nIV.2. ROLES & RESPONSIBILITIES  \n \nIV.2a. Election Commission will operate independent of the Student Life Department and \nreport to the faculty responsible for conducting elections.  \nIV.2b. They will be responsible for reviewing, interpreting and implementing the existing \nelection policy.  \nIV.2c. They must conduct a Townhall prior to kickstarting the election process and brief all the \ninterested candidates with all the requisite details and pertinent information.  \nIV.2d. The Commission will share an exclusive form to the candidates and they must submit \ntheir respective manifesto + vote support within 10 days from the date of Townhall.  \nIV.2e. They will be responsible for providing periodic updates to candi dates on the status of \nsupport votes.  \nIV.2f. The Commission will announce the candidature along with respective manifestos of \ncandidates to all the students. They will be responsible for co-ordinating with the Programmes \nTeam and Student Life Department to check candidate eligibility and communicating the same \nto all the concerned parties.  \nIV.2g. The Commission will assist candidates during their 3-week campaigning period and will \nensure that campaigning does not clash with any other planned activities such as Placement \nWeek for either of the cohorts.  ',
#   'page': 9,
#   'section': 'IV.ELECTION COMMISSION',
#   'source': 'constitution.pdf'},
#  {'text': '9 \n \n \nIV.2h. Along with the Student Life Department, they will make all the arrangements for the \nElection Day and ensure a smooth, fair voting process. The Commission will also be \nresponsible for announcing the results to all the students and for organising the swearing in \nceremony of the newly elected council.  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ',
#   'page': 10,
#   'section': 'IV.ELECTION COMMISSION',
#   'source': 'constitution.pdf'},
#  {'text': '10 \n \n \nV.COMMITTEES \n \nBITSoM Student led Committees incorporate an array of domains and are constituted with the \naim of nurturing team spirit, fostering leadership skills and curating responsible professionals \nthrough real life engagements within specific committees. Each Commi ttee is governed and \nmentored by the administrative head of the respective domain and they work together for \nthe welfare of the school. The KPIs and budget of a respective committee is decided by the \ngoverning administrative department. Any new committee i n its first year of operation will \nfollow a flat structure and fall within the purview of VP Committees and concerned \nadministrative head.  \n \nV.1. POSITIONS OF RESPONSIBILITIES (PoRs) & ROLES  \n \nV.1a. President: The President shall be active in the governance of the Committee and, when \npresent, shall preside at all meetings of the Committee, see that all orders and resolutions of \nthe Committee are carried into effect, execute and deliver in Committee interests except as \notherwise directed. The Presid ent shall have such other duties and exercise such other \npowers, as the Committee shall prescribe from time to time. \nV.1b. General Secretary : The General Secretary shall, in the absence or disability of the \nPresident, perform the duties of the President an d perform such other functions as the \nCommittee shall prescribe from time to time. The execution by the General Secretary on \nbehalf of the Committee of any instrument shall have the same force and effect as if it were \nexecuted on behalf of this Committee by the President. \nV.1c. Junior Committee Members Recruitment : The selection of junior committee \nrepresentatives will commence post a formal introduction by the respective PoR holder of the \ncommittee. In case the PoR holder is not available, the president ca n nominate someone on \nbehalf of the committee. This session will help the students understand the functioning of the \nrespective committees, the roles, and responsibilities of the members, and get all their queries \nsolved live before the recruitment begins. The committee selection process should start soon \npost the introduction and finish within 3 weeks from that time. \nV.1c(i) Guidelines for junior member recruitment are as follows:  \nV.1c(i)a. Students can apply to a maximum of 3 Committees. \nV.1c(i)b.  The VP Committee will release 2 distinct forms – one for gathering  \ninterests/preferences and the other requiring SOPs for all the committees that a particular \ncandidate is interested in joining.  ',
#   'page': 11,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "11 \n \nV.1c(i)c. To ensure fairness, the preference list should not be visible to the senior committee \nmembers at any stage of the process. If asked during the interview, the students have the right \nto decline to answer the question without giving any reasoning. \nV.1c(ii) Students must fill  out the interest form and mark their preferences in it. After that, \nmust fill out the SOP forms only for the committees that they had selected in the first form. It \nis mandatory to fill out both types of forms, failing which the student will be eliminated from \nthe selection procedure. \nV.1c(iii) The VP Committee should send all the SOPs received to the respective committee \npresident. The committee president shall discuss th ese with the members and create a \nshortlist for further processing.  \nV.1c(iv) After the initial screening round, every committee can have different procedures to go \nahead, this should be accepted by the VP Committee and the respective admin head. This \nprocess should be declared during the Round 1 of results along with the shortlist.  \n \nV.1c(v) All committee Presidents/ PoRs should send their preferred process of selecting \nstudents at least 1 week before the announcement of the round 1 shortlist to the VP \nCommittee. Post this,  the VP committee should discuss the process with each of the \ncommittee President/PoR and the admin head for the final approval of the same. \nV.1c(vi) At the end, along with the list of the selected students, the committee should give a \nwaitlist of at least 100% of their proposed committee strength to the VP Committee. \nV.1c(vii) After receiving the list of selected and waitlisted candidates from each committee, \nthe VP Committee shall check the students' preference in case of multiple committee \nselections by a student and then release the final list of selected candidates. \nV.1c(viii) In case the waitlist is exhausted or there are vacant spots in the committee, the \ncommittee is free to run the recruitment process again after obtaining approval from the VP \nCommittee. \nV.1d. The number of members inducted in each committee can be less t han or equal to that \nof the previous year . However, if the committee wants to increase its strength, then a written \nrequest should be sent to the VP Committees and the admin head. VP Committees should \nmeet the admin head of that respective Committee and di scuss the need for the same. Post \nthis meeting, the Head of Student Life should be consulted for making the final decision. \nV.1e. It is the responsibility of the president of the respective committee to ensure fairness \nduring the recruitment process of their committee. They shall include and discuss the process \nwith the committee members. \nV.1f. It is the responsibility of the VP Committee to conduct the entire recruitment process \nefficiently and within the given time frame. In case they feel anyone is violating the ethics, \nthey ha ve the right to take necessary actions after discussing it with th e Student Life \nDepartment. ",
#   'page': 12,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "12 \n \nV.1g. In case any Committee PoR holder is unable to conduct the process within the given time \nframe, the VP Committee has the right to interfere in the process after obtaining permission \nfrom the respective Committee admin head. \nV.1h. The decisions taken by the administrative heads of respective committees and the Head \nof Student Life will be final and binding to all the processes related to the functioning of the \ncommittee.  \nV.1i. Each committee can comprise of maximum 6 students from Year 1 and 6 students from \nYear 2, hence the maximum limit of members in every committee is 12. The only exception to \nthis rule is the Placement & Career Services Committee, wherein a maximum of 8 students \nfrom each year will be selected , making the total number of members 16. The Student Life \nDepartment s hall not entertain any requests for increase in number of members for any \ncommittee.  \n \nV.2. JUNIOR TO SENIOR COMMITTEE TRANSITION \n \nV.2a. VP Committees will be responsible for releasing the interest and SOP form to junior \nmembers of all the committees for their transition to senior members.   \n \nV.2b. VP Committees will share the received SOPs to the respective committee PoR and \nconcerned admin head. Senior Committee members and admin heads will screen and review \nthe SOPs and finalize candidates. They will sha re these details with VP Committees who in \nturn will make the official announcement.  \nV.2b. Once the shortlisted candidates are announced, VP Committees will release 2 separate \nforms, one for selecting new PoR holders among selected current members and another one \nfor filling up vacant seats, if any.  \nV.2c. Finalized candidates will be screened through interviews that will be conducted by a \npanel comprising of Senior Committee PoRs, VP Committees and concerned administrative \nheads.  \nV.2d. VP Committees will  conclude the transition process by announcing new senior \ncommittee members and PoRs for each committee.  \nV.2e. Guidelines for transition are detailed as follows:  \nV.2e(i). Each committee will have a position for President and a General Secretary from the \nsenior batch.  \nV.2e(ii). Positions can be left empty in case the selection panel doesn’t find a suitable candidate \nor there's no application. \nV.2e(iii). Members should be elected towards the end of their 1st year during the transition \nperiod.  ",
#   'page': 13,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': '13 \n \nV.2e(iv). There will be no provision for Joint Secretary PoR in any of the junior committees. \nAny request for the same will not be entertained.  \nV.2e(v). SOP form submissions must reflect member’s vision and contributions till date. \nV.2e(vi). It is essential to maintain transparency throughout the transition process. All PoRs \nmust co-ordinate with respective administration heads, VP Committees and Head of Student \nLife.  \nV.2e(vii). The li st of selected transitioning members must be approved by respective \nadministrative heads and VP Committees. In case of any disagreement/conflict the decision of \nthe concerned administrative head will be final and binding.  \nV.2e(viii). The VP Committees must conduct transition process for all committees \nsimultaneously. In case of any unmitigated situation, it can be delayed for a particular \ncommittee(s). VP Committees must share the timeline of all transition processes to all the \nstakeholders via email at least 10 days in advance.  \nV.2e(ix). In case any committee PoR holder is unable to conduct the process within the given \ntime frame, the VP Committee should interfere in the process after obtaining permission from \nthe concerned administrative head of the committee.  \nV.2e(x). Senior Committee members have the authority of recruiting junior members for \nvacant spots at their discretion and by keeping the administrative head informed about the \nsame.  \nV.2e(xi). For selecting new PoR holders, it is mandatory for the admin istrative head to be \ninvolved in the process along with at least 2 members from the senior committee. The VP \nCommittees can get involved in the selection processes if necessary. \n \nV.3. COMMITTEE FEEDBACK & REVIEW  \n \nFeedback and review for all committees must be conducted twice a year: once at the end of \nTerm 1 and Term 2, referred to as "Term-End Reviews," and once before the end of the year, \nknown as the "Year-End Review." These reviews will be intended to assess the productivity of \nall committee members and ensure the effective operation of each committee. \nFeedback must comprise of a detailed report highlighting contributions of each member to \nthe respective committee and entail peer review among the members, an open forum for a \ndiscussion and feedback on respective members and an option of exiting the commi ttee, if \nmet with consensus. The following guidelines must be adhered to for gathering feedback and \nconducting review exercises across all committees:  \nV.3a. The Term-End Review for the senior committee will be conducted by VP Committees, \nwhereas the tern end review for junior members will be conducted by the corresponding \nsenior committee PoRs.  ',
#   'page': 14,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "14 \n \nV.3b. The Year-End Review must begin 5 weeks before the end of the year and be completed \nat least 3 weeks prior to ensure a smooth transfer of knowledge & requisite information from \nsenior committee members. \nV.3c. The yearend review must act as a benchmark for transitioning junior committee \nmembers to senior roles within the committee.  \nV.3d. Remarks&/comments in the review of senior committee members must be kept \nconfidential and only a summary report should be provided to the concerned administrative \nheads and the committee president. This summary report must be shared by VP Committees \nand should not name any specific member(s).  \n V.3e. The peer review reports of senior committee members must be shared with respective \nadministrative heads by VP Committees.  \nV.3f. The peer review reports and contribution reports of junior committee members must be \ncollated by PoRs and shared only with VP Committees and respective administrative heads.  \nV.3g. VP Committees must share peer review and contribution reports of all senior committee \nmembers with respective PoRs and administrative heads.  \nV.3h. VP Committees must discuss feedback & review reports of each committee with \nadministrative heads and devise solutions for improvement &/fixing gaps /issues that may \nhave got highlighted during the process.  \nV.3i. During the review process, if a member is found to be unsatisfactory in terms of \ncontribution to the committee/taking initiati ves/following set procedures, the member will \nbe put on a 1-month probation. VP Committees and respective administrative head will review \nthe member ’s performance post probation and if there is still no improvement, the said \nmember will be removed from the committee.  \n \nV.4. RESIGNATION OF COMMITTEE MEMBERS  \n \nV .4a. Any member of any committee can quit their membership and resign from their position. \nThe resignation must be clear, precise and should mention the rationale behind the decision. \nIt should be submitted to PoR, VP Committees & Administrative Head.   \n \nV.4b. If a person leaves the committee before the end of term 2, and more than or equal to \n2/3rd of the members confirms diligent work of the student – the student won't be entitled to \nany CV points from the committee, however, they will be free to join any other committee \nwhenever there's an opening. \nV.4c. If a person leaves the Committee before the end of term 2, and less than 2/3 rd of the \nmembers confirms the diligent work of the student – the student won't be entitled to any CV \npoints from the committee, and they will be barred from joining any other committee in \nfuture. ",
#   'page': 15,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "15 \n \nV.4d. If a person leaves the committee after term 2, the student won't be entitled to any CV \npoints from the committee, and they will be barred from joining any other committee in the \nfuture. \nV.4e. VP Committees must gather feedback from all committee members be fore taking any \ndecision on a member’s resignation.  \nV.4f. Senior stakeholders might ask the member to reconsider their decision, in such a case, \nthe member must revert with the final decision within 24 hours. If the member persists on \nquitting, their resignation will be accepted.  \nV.4g. To replace a member who has resigned, the committee must select the new member \nfrom the waitlist submitted to the VP Committees at the time of committee selections. If the \nwaitlist is exhausted, or the committee wants to select someone new, they can proceed with \nthe process after obtaining permission from the VP Committees and admin head. \n \nV.5. TERMINATION /IMPEACHMENT POLICY  \n \nV.5a. Termination of junior committee members must be under the purview of senior \ncommittee, VP Committees and the concerned administrative head.  \nV.5b. Termination of senior committee members must be under the purview of senior \ncommittee PoRs, VP Committees and administrative head.  \nV.5c. Termination of senior committee PoR must be under the governance of VP Committees \nand administrative head.  \nV.5d. Termination will be considered in the following cases:  \nV.5d(i). For committee members, if the PoR holder determines, based on the term or year-end \nreview, that a member has not performed diligently or has provided incorrect information, \nthe PoR must consult with the VP of Committees to discuss the possibility of termination. If \nboth parties agree, the member w ill be placed on a one -month probation period to address \nthe issues. The respective admin head should be kept informed throughout this process. If an \nagreement cannot be reached, the decision of the admin head will be final. \nV.5d(ii). In case of some speci fic incident related to the functioning of the member, which \nhighlights the member's incompetency, lack of motivation, or integrity, the respective PoR \nholder can reach out to the VP Committees and the admin head to discuss the grounds for \ntermination. \nV.5d(iii). Termination procedure for committee PoRs will be the same as that of other \ncommittee members, detailed in V.5d(i). It will be governed by VP Committees and concerned \nadministrative head.  \nV.5e. Terminated member will not be eligible for any CV poin ts corresponding to their \nmembership &/position.  ",
#   'page': 16,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': '16 \n \nV.5f. If the concerned member has any grievances, they can report the matter to the VP \nCommittee/admin head. The decision taken by the admin head shall be final and binding. \nV.5g. To replace a member who ha s been terminated, the committee can select the new \nmember from the waitlist submitted to the VP Committee s at the time of committee \nselections. If the waitlist is exhausted, or the committee wants to select someone new, they \ncan proceed with the process after obtaining permission from the VP Committees and admin \nhead. \n \nV.6. CV VERIFICATION OF COMMITTEE MEMBERS \n  \nV.6a. It is mandatory for all committee members to get their CVs vetted from senior \nstakeholders and follow the prescribed protocol for obtaining  CV points. Any deviation or \nunverified CV will lead to disciplinary action against the member. In case of activities that will \nbe carried out post  or during  CV verification process, members must highlight that these \nactivities will be executed later or are in the middle of execution.  \nV.6b. All committee members are required to submit their CV pointers to their respective \ncommittee president. The president will review these submissions, identify any issues or \ndiscrepancies, and then send a compiled list to the VP Committees. \nV.6c. The committee president must not make any edits to the submitted CV, they can make \nsuggestions, if the member is willing, the revised CV can be submitted to the VP Committees.  \nV.6d. VP Committees must act as a second pedestal for  reviewing and suggesting changes, if \nany on the submitted CVs. Once the compilation if complete and finalized, VP Committees will \nsubmit the same to respective administrative heads, who will have the sole authority of \nverifying CV points.  \nV.6e. The proce ss of CV verification by the committee president, VP Committees and \nadministrative head must not exceed 2 weeks. Hence, verification by each stakeholder must \nnot exceed 4 days.  \n \nV.7. INTRODUCTION OF A NEW COMMITTEE  \n \nV.7a. If the VP Committees &/or President of the Council propose a new committee, they must \nadhere to the following:  \nV.7a(i). Reach out to the Student Life Associate with a proposal mentioning the clear need for \nthe formation, roles, and responsibilities of the members and the committe e, admin \ninvolvement, benchmarking other B-Schools, etc. \n ',
#   'page': 17,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': '17 \n \nV.7a(ii). Post this, a meeting must be organized with the Head of Student Life for an engaging \ndiscussion post which the final decision will be taken.  \n \nV.7b. If any student wants to propose a new committee, they must adhere to the following:  \n \nV.7b(i). The student must submit a detailed proposal highlighting the need, benefits, \ninclination, benchmarking examples to VP Committees. The proposal must be revi ewed \ninternally by the President & VP Committees.  \n \nV.7b(ii). If the President & VP Committees are in consensus, they must discuss the proposition \nwith Head of Student Life and proposed administrative head. If all the stakeholders agree, the \nnew committee will be constituted.  \n \nV.7c. If a new committee is formed, it will be on probation for an entire academic year, post \nwhich it will be reviewed for granting permanent status.  \n \nV.8. CODE OF CONDUCT  \n \nAll Committees are governed by a set of guidelines that govern their functions at all levels. \nThey outline the expected conduct for individuals, ensuring that all members adhere to shared \nvalues and principles. By setting clear expectations for professionalism, integrity, and respect. \nThe Code of Conduct fosters a positive environment, promotes fairness, and helps prevent \nconflicts.  \nV.8a. Integrity and Professionalism: All committee members must act with honesty and \nintegrity in all activities, maintaining transparency in decision-making and communication. \nThey must respect the confidentiality of sensitive information, not disclose it to unauthorized \nparties, and take responsibility for their actions and decisions, acknowledging mistakes and \nlearning from them. \nV.8b. Respect and Inclusivity: All members must foster an inclusive environment that \nembraces diversity in thought, background, and perspective. They should treat each other, \nfaculty, staff, and external stakeholders with respect and courtesy at all times, while promoting \ncollaboration, ensuring every member feels valued and heard, and encouraging teamwork and \nmutual support. \nV.8c. Commitment and Responsibility: Members are expected to regularly attend meetings \nand events, be punctual for all deadlines, and actively contribute to the committee’s goals and \nobjectives. If unable to attend, they must inform the committee in advance, and late \nsubmissions or arrivals should be minimized and justified. Passive participation is discouraged. \nV.8d. Ethical Leadership: Decisio ns must be made based on merit and fairness, avoiding \nfavouritism or bias. Members should avoid conflicts of interest, disclosing any potential ',
#   'page': 18,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "18 \n \nconflicts immediately, and maintain transparency in all processes to build and sustain trust \nwithin the committee and with external stakeholders. \nV.8e. Communication and Conduct: All communication, both within the committee and with \nexternal parties, should be clear, respectful, and professional. Feedback should be \nconstructive, aiming to improve outcomes and relationships. Members always represent the \ncommittee and BITSOM and should conduct themselves in a manner that upholds the values \nand reputation of the institution. \nV.8f. Compliance with Policies: Members must follow all BITSoM policies and procedures, \nadhere t o budget and financial guidelines set by administrative heads, use resources \nefficiently and responsibly, and ensure that all activities comply with applicable laws, \nregulations, and ethical standards. \nV.8g. Conflict Resolution: Disputes or disagreements within the committee should be resolved \namicably through discussion; if unresolved, escalate to the administrative head or VP \nCommittees. Conflicts with external parties should be handled professionally, seeking \nmediation if necessary. \nV.8h. Continuous Improvement: Regularly seek and provide feedback to enhance committee \nfunctioning and personal growth and engage in opportunities for learning and development \nto improve skills relevant to committee roles. \n \nV.9. EVALUATION CRITERIA  \n \nThe evaluation of student -led committees at BITSoM is an essential process designed to \nensure that these committees operate effectively, contribute positively to the institution, and \nprovide meaningful learning experiences for all members. The evaluation aims to assess the \nperformance, impact, and development of each committee, focusing on various aspects such \nas goal attainment, member engagement, adherence to policies, and overall contribution to \nthe BITSoM community. \nV.9a. Achievement of Objectives:  Measure the extent to which the committee has met its \nstated goals and objectives, and evaluate the successful completion of projects, events, or \ninitiatives as planned. \nV.9b. Performance and Productivity: Assess the quality and impact of the committee's work, \nincluding events, reports, and other deliverables, and review adherence to deadlines and \nschedules for meetings, events, and deliverables. \nV.9c. Member Engagement and Contribution:  Evaluate the level of active participation and \ncontribution from each member and assess the effectiveness of teamwork and collaboration \namong committee members. ",
#   'page': 19,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "19 \n \nV.9d. Adherence to Code of Conduct: Measure adherence to the established Code of Conduct, \nincluding integrity, respect, and ethical behaviour, and review the handling and resolution of \ninternal and external conflicts. \nV.9e. Communication Effectiveness: Assess the clarity, respectfulness, and professionalism of \ninternal and external communications, and evaluate how effectively feedback is sought, \nprovided, and implemented. \nV.9f. Resource Management: Review compliance with the budget and financial guidelines, \nincluding the efficient and responsible use of resources, and assess the effective use of \navailable resources and facilities. \nV.9g. Compliance and Governance: Evaluate adherence to BITSoM policies, procedures, and \nlegal and ethical standards, and review alignment with the committee's governing bodies and \nadministrative guidelines. \nV.9h. Impact and Innovation:  Measure the impact of the committee ’s work on the school \ncommunity and stakeholders and assess the introduction and implementation of innovative \nideas and approaches. \nV.9i. Feedback and Continuous Improvement: Review how effectively the committee \nintegrates feedback for improvement and assess the committee's adaptability to change and \nits commitment to continuous improvement. \n \nV.10. EXISTING COMMITTEES  \n \nV.10a.  ACADEMIC COMMITTEE  \n \nThe Academic Committee oversees the overall academic milieu comprising of adherence to \nacademic standards, emergent academic practices in business education, additions to the \ncurriculum, research etc. It falls under the ambit of the Programmes Team and supports them \nin their endeavour of offering quality par excellence education to the students. In addition to \nconducting periodic review of the curriculum & teaching methodology, the Committee also \nconducts workshops/seminars on academic research, paper presentations and allied subjects \npertaining to academics.  \n \nV.10b.  ADMISSIONS, COUNSELLING & ENGAGEMENT (ACE) COMMITTEE \n \nThe Admissions, Counselling, and Engagement (ACE) Committee acts as a catalyst between \nthe school and its prospective students. Working in collaboration with the official admissions \nteam, the ACE Committee embodies the spirit of guidance and support, ushering candidates ",
#   'page': 20,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "20 \n \nthrough the transformative journey from aspirants to admits. The essence of ACE lies in its \nname – facilitating a seamless and enriching experience for every candidate from start to \nfinish. The Committee manages interactive platforms, creating a dynamic and supportive \ncommunity where aspirants and admits can connect, share, and learn. Its involvement \nencompasses personalized p rofile evaluations, helping candidates to understand and align \ntheir aspirations with BITSoM’s offerings.  \n \nV.10c.  ALUMNI RELATIONS COMMITTEE (ARC)  \n \nThe Alumni Relations Committee (ARC) acts as a pivotal link between the school and its alumni \nby creating & maintaining relationships that transcend the limitations of time. It is entrusted \nwith the task of maintaining a strong bond between the institute, its distinguished alumni, \nand the vibrant student community. The Committee oversees the procedure of enro lling \ngraduating students into the Alumni network, provides opportunities of mentorship for \ncurrent students, leverages alumni expertise for incorporating emergent industry trends, \nconducts alumni get together and establish a thriving, engaging community d edicated \ntowards carrying on the legacy of the school.  \n \nV.10d.  EVENTS & CULTURAL COMMITTEE (ECC)  \n \nAs evident from the name, Events & Cultural Committee (ECC) is responsible for conducting \ncultural & social events on campus. ECC is committed towards celebration of diversity and \nworks closely with the school administration for organising myriad of activities &/celebrations \nto commemorate festivals, traditional events, professional occasions, milestones etc. ECC \nenvisions a future at BITSoM where diverse cultures harmonize, forging enduring bonds \nthrough extracurricular festivities, shaping a vibrant and f amilial college experience that \ntranscends textbooks and propels the institution into a legacy of cultural richness. With \nsupport from school administration, the Committee handles all aspects of organizing events – \nfrom venue to budgets, obtaining approvals, planning activities, arranging performances & all \nother material/logistical/resource requirements.  \n \n V.10e. MARKETING COMMITTEE \n \nMarketing Committee is responsible for supporting the administration for promoting the \nschool and shaping its image and reputation within the educational landscape and broader \nsociety. One of the primary functions of the marketing committee is to collaborate closely with \nthe administration to devise comprehensive marketing plans and campaigns that effectively \nshowcase BITSoM's unique value proposition, academic offerings, faculty expertise, campus ",
#   'page': 21,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
#  {'text': "21 \n \nfacilities, and student achievements. These efforts are aime d at differentiating BITSoM from \nother B-schools and creating a compelling narrative that resonates with the target audience. \nThe marketing committee employs a comprehensive, multi-channel strategy to engage diverse \nstakeholders, utilizing digital avenues like social media, SEO, and online advertising for \nincreased brand visibility. Traditional methods such as campus events, and industry \nconferences are also leveraged to establish connections and foster brand loyalty. \n \nV.10f. OPERATIONS COMMITTEE \n \nThe Operations Committee serves as the institution's internal engine, meticulously ensuring \nits day-to-day functions run smoothly and efficiently. From managing logistics for academic \nprograms and events to overseeing infrastructure maintenance and IT support, thei r \nmeticulous efforts ensure a seamless experience for everyone within BITSoM's vibrant \ncommunity. Whether it's facilitating classroom resources, optimizing administrative \nprocesses, or resolving concerns promptly, the committee prioritizes efficiency and \nresponsiveness, upholding the high standards expected of a leading B -school. Beyond \nmaintaining day-to-day operations, the committee plays a crucial role in strategic planning and \nimprovement. Through collaboration with various departments and committees, t he \nOperations Committee fosters a culture of continuous improvement, ensuring BITSoM adapts \nto evolving needs and thrives in a dynamic educational landscape. \n \nV.10g. PLACEMENTS & CAREER SERVICES COMMITTEE  \n \nPlacements & Career Services Committee is respons ible for the enactment of the placement \npolicy, for proper placement processes to be implemented and to bridge the gap between the \nIndustry Partnership & Career Services team and the students and take care of the various \naspects of placements, such as, CV, CLP , Leadership talks, Spotlight events, Interviews, etc. The \nCommittee is dedicated to providing comprehensive career services, fostering industry \nconnections, and facilitating access to a diverse array of employment opportunities. By \nnurturing professional growth & excellence through personalised career guidance, leveraging \nBITS alumni network & corporate partnerships, the committee aims to equip students with \nthe tools, knowledge and opportunities to thrive in their areas of interest and contribute \nmeaningfully to the business community.  \n \n \n \n ",
#   'page': 22,
#   'section': 'V.COMMITTEES',
#   'source': 'constitution.pdf'},
# ...
#   'page': 35,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'},
#  {'text': "35 \n \nVI.15f. All venue reservati ons for club events must be made through the Student Council. \nReservations made through any other channels shall not be recognized or accepted. \nVI.15g. Clubs are responsible for the proper upkeep and maintenance of any venues, spaces, \nor equipment used for events or meetings. Any damage or misuse of these resources shall be \nthe responsibility of the club. \nVI.15h. Each club shall have no more than 24 active members, with a maximum of 12 members \nfrom any single cohort. \nVI.15i. All club-related activities must be approved by the VP of Clubs prior to the initiation of \nany preparations. \n \nVI.16. FORMATION OF A NEW CLUB \n \nVI.16a. Any student may initiate the formation of a new club or committee, provided there is \na demonstrated need for such a club within the institution, alongside a clear outline of its \nfinancial requirements. Furthermore, there must be documented interest from a t least 15% \nof the student body from each cohort in the proposed club's area of focus. These requisites \nmust be formally documented by the initiating student and submitted to the Head of Student \nLife for approval. \nVI.16b. Should the Head of Student Life de em the proposal valid, it will be forwarded to the \nExecutive Council for further deliberation. \nVI.16c. Upon receiving approval from the Executive Council, the proposed club shall undergo \na three -month probationary period, functioning as an interest club be fore finalizing its \nestablishment. \nVI.16d. The probationary period shall commence on the day the club is formally announced \nto both cohorts. \nVI.16e. The club’s performance during the probationary period shall be evaluated based on \nspecific metrics, as assessed by various stakeholders at the end of the probation period. \nVI.16f. At the conclusion of the probationary period, the Student Life Department and the \nExecutive Council shall conduct a review of the interest club. A final decision on the club's \nstatus will be made at that time, which shall be binding on all parties. \nVI.16g. If the proposal is initiated by a single student, that student shall assume the role of \nPresident of the club. In cases where two or more students share the proposal, they shall \nmutually decide among themselves who will assume the role of President. \nVI.16h. Students who are already members of two bodies (e.g., two clubs or one club and one \ncommittee) shall not be eligible to join the newly formed club. ",
#   'page': 36,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'},
#  {'text': "36 \n \nVI.16i. The new club shall have one opportunity to recruit members during its probation \nperiod and will not be permitted to recruit additional members during this time. \nVI.16j. During the probationary period, the club may have a maximum of six members, \nincluding the President and General Secretary. These six members shall be considered the co-\nfounding members of the club. \n \nVI.17. EXISTING CLUBS \n \n \n \nVI.17a. PROFESSIONAL CLUBS \n \nProfessional clubs are an integral part of the BITSoM ecosystem, providing platforms that \nbridge academic learning with practical business applications. These clubs are designed to \nsupport the personal and professional growth of students by aligning with their diverse career \ninterests and aspirations. Each club facilitates a variety of activities that enhance skill \ndevelopment, industry engagement, and networking opportunities. These activities may \ninclude guest lectures, workshops, case competitions, networking events, and career-focused \ninitiatives that offer members valuable exposure to real -world challenges and busi ness \npractices. \nVI.17a(i). CONSULTING CLUB / BITSoM Consulting Club (BCC) \n \nThe BITSoM Consulting Club organizes events, sessions, and case competitions for the student \ncommunity to strengthen their consulting acumen, enhance structural thinking, and develop \nproblem-solving capabilities. Additionally, we offer valuable resources such as the BITSoM \nConsulting Club & Industry Primers to support students in their internship and final placement \npreparation. \nVI.17a(ii). BUSINESS ANALYTICS CLUB/ PreQL \n \nPreql, BITSoM's Business Analytics club, is committed to equipping students with essential \nanalytics skills across corporate functions, aiming to become a global leader with strong recall \namong management professionals. Through workshops, newsletters, and colla borative \nprojects, the club fosters hands-on learning, providing a platform to experiment and showcase \nanalytical capabilities. \nVI.17a(iii). ENTREPRENEURISHIP CLUB ",
#   'page': 37,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'},
#  {'text': "37 \n \n \nThe Entrepreneurship Club supports students with entrepreneurial ambitions by providing a \nspace for innovation, creativity, and exploration of market dynamics and trends. The club \norganizes events with startup founders and industry leaders to share insights, discuss real -\nworld challenges, and guide students through the entrepreneurial journey f rom idea \ngeneration to execution. \nVI.17a(iv). FINANCE CLUB / Pennywise \n \nThe Finance Club, Pennywise, is focused on facilitating comprehensive discussions and \nexplorations in the field of finance. Covering topics such as financial markets, revenue models, \ninvestments, banking, and accounting, the club offers members a chance to deepen their \nunderstanding of the financial landscape through workshops, seminars, and peer interactions. \n \nVI.17a(v). MARKETING CLUB / BITSvertise \n \nBITSVertise exists to ignite a passion for marketing within the BITSoM community by \nsimplifying complex marketing concepts and connecting students to real -world trends. Our \nmission is to make marketing fun, engaging, and relevant through dynamic content li ke \nnewsletters and primers. We've sparked creativity with events like AdZap and Brand Hunt and \nproudly hosted BITSoM’s first inter-college case competition last year . Beyond events, we also \nsupport students with placement prep by offering company primers, CV guidance, and \ninterview mentorship to help them excel in their careers. \n \nVI.17a(vi). OPERATIONS & GENERAL MANAGEMENT CLUB \n \nThe Operations & General management Club provides a dynamic platform for students to \nexplore their interests in general management, operations, supply chain, and decision-\nmaking. Through group discussions, guest lectures, and case competitions, the club fosters \nan environment of hands-on learning and peer collaboration. Notable past events include \nthe insightful Dabbawalla session and BITSoM’s first-ever fully funded case competition in \npartnership with the Maharashtra State Khadi & Village Industries Board.  \n \nVI.17a(vii). PUBLIC POLICY CLUB / Mandate \n \nThe Mandate Public Policy Club offers a platform for understanding the intersection of \nbusiness, government, and society. The club studies regulatory frameworks and government \npolicies, analysing their impact on industries globally, thereby preparing members for a \ndeeper understanding of public policies and their role in shaping economic landscapes. ",
#   'page': 38,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'},
#  {'text': '38 \n \n \nVI.17a(viii). SUSTAINABILITY & SOCIAL IMPACT CLUB  \n \nThe Sustainability and Social Impact Club at BITSoM is dedicated to fostering a culture of \nenvironmental responsibility and social consciousness among future business leaders. The \nclub drives initiatives that align with the UN Sustainable Development Goals, encouraging \nstudents to integrate sustainability into their personal and professional lives. Through \nworkshops, guest lectures, and community engagement projects, SSIC actively contributes to \ncreating a positive social and environmental impact, preparing members to lead with \npurpose and integrity in the business world. \n \nVI.17a(ix). PRODUCT MANAGEMENT CLUB / ProdMan Club \nThe Product Management Club provides a platform for students interested in the discipline of \nproduct management to gain insights and hands-on experience. The club focuses on exploring \nthe lifecycle of product development, from ideation and market research to design, \ndevelopment, and launch. Members engage in activities such a s product case competitions, \nworkshops on product strategy, user experience design, and roadmap planning. \n \nVI.17a(x). DIVERSITY , EQUITY AND INCLUSION CLUB / DEI Club \nThe DEI Club is dedicated to fostering an inclusive community where every individual feels  \nvalued, respected, and empowered. The club believes that diversity, equity, and inclusion are \nnot just buzzwords but essential pillars for personal and professional growth. The mission is \nto create a supportive environment that celebrates differences and promotes equal \nopportunities for all. \n \nVI.17b. TALENT CLUBS \nTalent clubs at BITSoM provide students with opportunities to explore their creative interests, \npursue passions, and develop skills beyond the academic realm. These clubs offer a supportive \nenvironment for students to engage in activities ranging from music and theatre to fitness and \npublic speaking. The institution currently supports the following talent clubs: \n \nVI.17b(i). THEATRE CLUB / Rang Bhoomi \n \nRanghbhoomi, the theatre club of BITSoM, is dedicated to celebrating the art of storytelling \nthrough live performances. It provides a platform for students to explore creativity, develop \nacting and stagecraft skills, and bring impactful narratives to life. The club also organizes ',
#   'page': 39,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'},
#  {'text': "39 \n \nstreet plays, theatre performances, festival celebrations, photo booth memories, and \nengaging social media content. \n \nVI.17b(ii). BOOK READERS CLUB / Shelf-Indulgence \n \nShelf Indulgence is BITSoM's vibrant book club that fosters a love for reading and storytelling \nwithin the community. The club organizes various activities such as book fairs, writing \ncompetitions, quizzes, and themed discussions, creating a dynamic platform for literary \nenthusiasts. It aims to promote intellectual engagement, enhance analytical skills, and build \na sense of community among students through shared literary experiences. \n \nVI.17b(iii). CONTENT CLUB / SOCH – The Content House \n \nThe Content Club encourages students to express themselves through various forms of \ncontent creation, including writing, digital media, and visual storytelling. \nVI.17b(iv). DANCE CLUB / BITS ‘N’ TOES \n \nThe Dance Club, BITS ‘N’ TOES, offers a platform for students to explore various dance forms \nand express their passion for dance through performances and workshops. \n \nVI.17b(v). MUSIC CLUB / BEATSoM \n \nThe Music Club, BEATSoM, brings together students with a shared love of music. It provides \nopportunities for musical performances, jam sessions, and collaborations across genres. \n \nVI.17b(vi). SPoRTS & FITNESS CLUB / BITSoM Sports Club \n \nThe Sports Club at BITSoM is committed to promoting sports and fitness activities across the \ncampus, ensuring that all facilities are accessible to students. The club organizes a variety of \nsports competitions to encourage talent, teamwork, and inclusiv ity. By hosting indoor, \noutdoor, and e-sports events, the club aims to maintain a vibrant campus environment and \ncontinuously expand its offerings to cater to diverse student interests. \n \nVI.17b(vii). PUBLIC SPEAKING CLUB / Raise A Toast ",
#   'page': 40,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'},
#  {'text': '40 \n \n \nRaise a Toast" is the official public speaking club of BITSoM, dedicated to enhancing public \nspeaking and communication skills within the cohort. Through various initiatives and events, \nthe club provides a platform for members to practice and refine their speaking abilities  in a \nsupportive environment. These activities help participants gain confidence, overcome stage \nfear, and improve their overall communication skills. By fostering collaboration and \ncontinuous learning, “Raise a Toast” empowers its members by activities like informal speech \ndelivery sessions, elevator pitch challenges etc. \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ',
#   'page': 41,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'},
#  {'text': '41 \n \n \n \n \nANNEXURE- I  \n \nOATH FOR ELECTED MEMBERS OF THE BITSoM STUDENT COUNCIL \n \n \nOn my honour I ____(name of person)______  solemnly swear to fulfil my duties as a member \nof the student council to the best of my abilities. I pledge to serve my fellow students with \nintegrity, honesty, and compassion. \nI will strive to represent the interests and concerns of the student body, and work tirelessly to \nimprove the quality of student life on campus.  \nI promise to uphold the principles of equality, fairness, and respect, and to promote a culture \nof inclusivity and diversity in all aspects of campus life. \nI recognize the importance of communication and collaboration, and will engage wit h my \nfellow council members, faculty, and administration in a constructive and respectful manner.  \nI understand that my role as a student council member is a privilege, and I will honour this \nresponsibility by being accountable and transparent in all of my actions. \nWith this oath, I commit myself to the service of my fellow students, and to the betterment of \nour institution as a whole. \n \n \n \n \nX---X---X---X---X--X ',
#   'page': 42,
#   'section': 'VI. CLUBS',
#   'source': 'constitution.pdf'}]

# %%
# Out:
# Current line: 5  levels. All elected members must read, understand and sign the Code of Conduct within 48 hours of assuming office and must adhere to it and the constitution at all times.
# Current line: III.3. DUTIES
# 0.3335255062466194
# Current line: III.3. DUTIES
# Current line: III.3a. To safeguard the interests of the students and to ensure that the students' view is expressed in the BITSoM community, without compromising on the reputation, standards, values, morals and long-term interests of the Institute
# 0.4428357290930296
# Current line: III.3a. To safeguard the interests of the students and to ensure that the students' view is expressed in the BITSoM community, without compromising on the reputation, standards, values, morals and long-term interests of the Institute
# Current line: III.3b. To act as the mediato r as and when required between the students and the administration in the matters pertaining to the interests of any individual or the batch as a whole  III.3c. To monitor, aid and assist in the functioning of all clubs & committees, including organizing events, resolving operational difficulties / issues.
# 0.5730599745523012
# Current line: III.3b. To act as the mediato r as and when required between the students and the administration in the matters pertaining to the interests of any individual or the batch as a whole  III.3c. To monitor, aid and assist in the functioning of all clubs & committees, including organizing events, resolving operational difficulties / issues.
# Current line: III.3d. To decide on matters of importance to the student body as a whole.
# 0.606871615377356
# Current line: III.3d. To decide on matters of importance to the student body as a whole.
# Current line: III.3e. To call for meetings with admin members or students or both, mainly for discussing regular or routine activities and to review other important issues.   III.4. SCOPE OF OPERATIONS
# 0.6081636457293147
# Current line: III.3e. To call for meetings with admin members or students or both, mainly for discussing regular or routine activities and to review other important issues.   III.4. SCOPE OF OPERATIONS
# Current line: III.4a. Executive Council will be at the apex of the Student Council.
# 0.4611012423177719
# Current line: III.4a. Executive Council will be at the apex of the Student Council.
# Current line: III.4b. It will finalize the annual student activity plan for the year . Each club and committee will be required to submit an activity calendar which will be discussed with the council and subject to final approval by the Executive Council.
# 0.5787196003032736
# Current line: III.4b. It will finalize the annual student activity plan for the year . Each club and committee will be required to submit an activity calendar which will be discussed with the council and subject to final approval by the Executive Council.
# Current line: III.4c. All the activities submitted by the clubs and committees will be scheduled in the annual calendar by Executive Council.  III.4d. Executive Council will finalize the budget of every club and committee after discussing it with the Treasurer of every club and thereafter taking approval from the Head of Student Life.
# 0.8384796386072453
# Current line: III.4c. All the activities submitted by the clubs and committees will be scheduled in the annual calendar by Executive Council.  III.4d. Executive Council will finalize the budget of every club and committee after discussing it with the Treasurer of every club and thereafter taking approval from the Head of Student Life.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[103], line 3
#       1 for x in range(len(parts)):
#       2     print("Current line:", parts[x])
# ----> 3     print("Current line:", parts[x+1])
#       5     vector1=get_embedding(text_to_embed=parts[x],
#       6                         end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL)[0].data[0]["embedding"]
#       7     vector2=get_embedding(text_to_embed=parts[x+1],
#       8                         end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL)[0].data[0]["embedding"]
#
# IndexError: list index out of range

# %%
get_embedding(text_to_embed=parts[x],
                        end_point=AZURE_OPENAI_ENDPOINT,azure_key=AZURE_OPENAI_KEY ,model=EMBEDDING_MODEL)[0]
# Out:
# {'object': 'list', 'data': [{'object': 'embedding', 'index': 0, 'embedding': [-0.011682971, 0.0670343, 0.018965358, 0.03390658, 0.040812515, 0.048860785, 0.012364478, -0.00937234, -0.018108606, 0.0646977, 0.053585898, -0.051197376, 0.006539219, 0.0022587078, 0.070513226, 0.009554074, -0.009229547, 0.027260266, 0.00109609, 0.09496958, 0.01971826, 0.020899538, 0.012001008, 0.08686938, -0.044343367, -0.002636782, -0.021301951, -0.014318131, 0.017836003, -0.025287144, 0.036788378, -0.007918458, -0.046576113, -0.018407172, -0.020886557, 0.012805835, 0.0031819872, -0.034425825, 0.029259354, -0.058726404, -0.019199017, -0.020354332, -0.0060297116, -0.05363782, -0.023365943, -0.03460756, -0.02946705, 0.026741024, -0.044680875, 0.041201945, -
, 0.020497125, 0.029908407, -0.01983509, -0.0204452, 0.02079569, -0.0266891, 0.0013508436, 0.027467964, 0.011605085, 0.0024420656, -0.021107236, -0.0044784723, -0.013007042, 0.03489314, 0.010216109, 0.029441088, -0.028402602, 0.02777951, 0.032296926, 0.00080644956, -0.005205413, 0.0257285, -0.03655472, -0.0076134033, 0.06630735, -0.02296353, 0.009073774, 0.021704365, 0.0122 ...

# %%
reader = PdfReader(PDF_PATH)

# %%
print(len(reader.pages[35].extract_text()))
# Out:
# 2461

# %% [markdown]
# # Total Code Steps

# %%
# Example: GitHub-hosted Azure inference endpoint

embedding_client = EmbeddingsClient(
    endpoint=AZURE_OPENAI_ENDPOINT,
    credential=AzureKeyCredential(AZURE_OPENAI_KEY)
)
print("✅ Connected to Azure OpenAI Inference API")
# Out:
# ✅ Connected to Azure OpenAI Inference API

# %%
client = weaviate.connect_to_embedded(
    persistence_data_path="./.collections"
)
print("✅ Embedded Weaviate started")

# %%
COLLECTION_NAME = "PdfChunks"

if COLLECTION_NAME not in [c.name for c in client.collections.list_all()]:
    client.collections.create(
        name=COLLECTION_NAME,
        description="Stores token-overlapped PDF chunks with Azure embeddings",
        properties=[
            Property(name="text", data_type=DataType.TEXT),
            Property(name="page", data_type=DataType.INT),
            Property(name="source", data_type=DataType.TEXT),
        ],
    )
    print(f"✅ Created collection '{COLLECTION_NAME}'")
else:
    print(f"ℹ️ Collection '{COLLECTION_NAME}' already exists")

collection = client.collections.get(COLLECTION_NAME)

# %%
def chunk_text_with_overlap(text, chunk_size=400, overlap=60, model="text-embedding-3-small"):
    enc = tiktoken.encoding_for_model(model)
    tokens = enc.encode(text)
    chunks = []

    for i in range(0, len(tokens), chunk_size - overlap):
        chunk = tokens[i:i + chunk_size]
        chunk_text = enc.decode(chunk)
        chunks.append(chunk_text)

    return chunks

# %%
def read_pdf_chunks(pdf_path, chunk_size=400, overlap=60):
    reader = PdfReader(pdf_path)
    all_chunks = []

    for page_num, page in enumerate(reader.pages, start=1):
        text = page.extract_text() or ""
        page_chunks = chunk_text_with_overlap(text, chunk_size, overlap)
        for chunk in page_chunks:
            all_chunks.append({
                "text": chunk,
                "page": page_num,
                "source": os.path.basename(pdf_path)
            })
    return all_chunks

# %%
def get_embedding_azure(text):
    response = embedding_client.embeddings.create(
        model="text-embedding-3-small",
        input=[text]
    )
    return response.data[0].embedding

# %%
pdf_path = "your_file.pdf"  # Replace with your PDF
chunks = read_pdf_chunks(pdf_path)
print(f"📄 Extracted {len(chunks)} chunks from {pdf_path}")

with collection.batch.dynamic() as batch:
    for chunk in chunks:
        vector = get_embedding_azure(chunk["text"])
        batch.add_object(
            properties=chunk,
            vector=vector
        )

print("✅ All chunks embedded and stored in Weaviate!")

# %%
query = "What are the main challenges discussed in the document?"
query_vector = get_embedding_azure(query)

results = collection.query.near_vector(
    near_vector=query_vector,
    limit=3
)

print("\n🔎 Top Results:")
for o in results.objects:
    print(f"\n📘 Page {o.properties['page']} ({o.properties['source']}):\n{o.properties['text'][:300]}...")
