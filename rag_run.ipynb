# %%
from py_rag import *

# %%
llm_chatbot_constitution().continuous_chat()
# Out:
# ✅ Connected to Weaviate: True
# ℹ️ Collection 'student_constitution' already exists
# Query: what is eligibility to become member of executive student council?
# Assitant: The eligibility criteria to become a member of the Executive Student Council as per the student constitution are:
#
# - The candidate must be a member of the Student Council.
# - The candidate should have a CGPA greater than 3.
# - The candidate should not have any honor code violations.
# - The candidate should not have any disciplinary committee incidents on record.
# - The candidate should not have been impeached or removed from office.
# - If selected to a new post, the candidate must resign from membership of a committee or any Position of Responsibility (PoR) held.
# - The candidate should procure unique support of a minimum of 10% of eligible voters (the entire student cohort).
# ...
