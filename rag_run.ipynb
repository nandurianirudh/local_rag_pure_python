# %%
from py_rag import *

# %%
llm_chatbot_constitution().continuous_chat()
# Out:
# ✅ Connected to Weaviate: True
# ℹ️ Collection 'student_constitution' already exists
# Query: who can become president of council? What is eligibility criteria?
# {'answer': "I don't have enough information to answer that.", 'can_answer_from_system_info': False}
# Cleaned Query: What are the eligibility criteria to become president of the student council?
# Assitant: The eligibility criteria to become President of the Student Council (Executive Council) are as follows (Section III.5, pages 6-7):
#
# - The candidate must be a member of the Student Council.
# - The candidate should have a CGPA greater than 3.
# - The candidate should not have any honour code violations.
# - The candidate should not have any disciplinary committee incidents on record.
# - The candidate should not have been impeached or removed from office previously.
# - The candidate should procure unique support from a minimum of 10% of eligible voters (entire student cohort).
# ...
